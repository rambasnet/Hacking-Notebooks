# %% [markdown]
# # Executable and Linkable Format (ELF)
# - https://en.wikipedia.org/wiki/Executable_and_Linkable_Format
# - common format for executables files, object code, shared libraries, and core dumps
# <img src="./resources/ELF.png">
# - an ELF file has two views: the program header shows the segments used at run time, whereas the section header lists the set of sections of the binary.
# - let's compile the following program and examine ELF format using various tools

# %% [markdown]
# ```c
# // demo-programs/hello.c program
# #include <stdio.h>
# int main() {
#     puts("Hello World!");
#     return 0;
# }
# ```

# %%
# %%bash
# in=./demo-programs/hello.c
# out=hello
#
# gcc -g -o $out $in
# ./$out
# Out:
# Hello World!

# %%
! ls -al hello
# Out:
# -rwxr-xr-x 1 root root 17812 Mar 11 13:16 hello

# %%
! cat hello
# Out:
# �����������f�1�^����PTR�"�Ð/��@���P������PQV�����������$�f�f�f�f�f��$�f�f�f�f�f�f�����K/����9�t��������tU���Q�Ѓ��Ít&�Í�&���/U��S������)ȉ��������t��������t
# H�>�>���o��
# �L	�[vT	\�X	W]U\	�^	�`	�_
# �l1�
# :;9I8
# =Y
# h	�
# `H  d �>�>�>�?@@@����!@7@F�>m�y�>�������!����>��>��>� �@@ 0��@ FA\@Hc�y"�@�� �@� ���]� @�`6
# @0�00&B0 b0 m3�.94:0T5��7�!2	x<^�>E

# %% [markdown]
# ## file utility
# - displays some information about ELF files

# %%
! file ./demo-programs/hello.c
# Out:
# ./demo-programs/hello.c: C source, ASCII text

# %%
! hexdump -C hello
# Out:
# 00000000  7f 45 4c 46 01 01 01 00  00 00 00 00 00 00 00 00  |.ELF............|
# 00000010  03 00 03 00 01 00 00 00  60 10 00 00 34 00 00 00  |........`...4...|
# 00000020  1c 40 00 00 00 00 00 00  34 00 20 00 0b 00 28 00  |.@......4. ...(.|
# 00000030  23 00 22 00 06 00 00 00  34 00 00 00 34 00 00 00  |#.".....4...4...|
# 00000040  34 00 00 00 60 01 00 00  60 01 00 00 04 00 00 00  |4...`...`.......|
# 00000050  04 00 00 00 03 00 00 00  94 01 00 00 94 01 00 00  |................|
# 00000060  94 01 00 00 13 00 00 00  13 00 00 00 04 00 00 00  |................|
# 00000070  01 00 00 00 01 00 00 00  00 00 00 00 00 00 00 00  |................|
# 00000080  00 00 00 00 b8 03 00 00  b8 03 00 00 04 00 00 00  |................|
# 00000090  00 10 00 00 01 00 00 00  00 10 00 00 00 10 00 00  |................|
# 000000a0  00 10 00 00 5c 02 00 00  5c 02 00 00 05 00 00 00  |....\...\.......|
# 000000b0  00 10 00 00 01 00 00 00  00 20 00 00 00 20 00 00  |......... ... ..|
# 000000c0  00 20 00 00 a0 01 00 00  a0 01 00 00 04 00 00 00  |. ..............|
# 000000d0  00 10 00 00 01 00 00 00  f4 2e 00 00 f4 3e 00 00  |.............>..|
# 000000e0  f4 3e 00 00 28 01 00 00  2c 01 00 00 06 00 00 00  |.>..(...,.......|
# 000000f0  00 10 00 00 02 00 00 00  fc 2e 00 00 fc 3e 00 00  |.............>..|
# 00000100  fc 3e 00 00 f0 00 00 00  f0 00 00 00 06 00 00 00  |.>..............|
# 00000110  04 00 00 00 04 00 00 00  a8 01 00 00 a8 01 00 00  |................|
# 
# 000033d0  03 0e 3a 0b 3b 0b 39 0b  49 13 38 0b 00 00 0a 16  |..:.;.9.I.8.....|
# 000033e0  00 03 0e 3a 0b 3b 0b 39  0b 00 00 0b 13 00 03 0e  |...:.;.9........|
# 000033f0  3c 19 00 00 0c 01 01 49  13 01 13 00 00 0d 21 00  |<......I......!.|
# 00003400  49 13 2f 0b 00 00 0e 34  00 03 0e 3a 0b 3b 0b 39  |I./....4...:.;.9|
# 00003410  0b 49 13 3f 19 3c 19 00  00 0f 21 00 00 00 10 2e  |.I.?.<....!.....|
# 00003420  00 3f 19 03 0e 3a 0b 3b  0b 39 0b 49 13 11 01 12  |.?...:.;.9.I....|
# 00003430  06 40 18 96 42 19 00 00  00 17 01 00 00 03 00 f7  |.@..B...........|
# 00003440  00 00 00 01 01 fb 0e 0d  00 01 01 01 01 00 00 00  |................|
# 00003450  01 00 00 01 2e 2f 64 65  6d 6f 2d 70 72 6f 67 72  |...../demo-progr|
# 00003460  61 6d 73 00 2f 75 73 72  2f 6c 69 62 2f 67 63 63  |ams./usr/lib/gcc|
# 00003470  2f 69 36 38 36 2d 6c 69  6e 75 78 2d 67 6e 75 2f  |/i686-linux-gnu/|
# 00003480  39 2f 69 6e 63 6c 75 64  65 00 2f 75 73 72 2f 69  |9/include./usr/i|
# 00003490  6e 63 6c 75 64 65 2f 69  33 38 36 2d 6c 69 6e 75  |nclude/i386-linu|
# 000034a0  78 2d 67 6e 75 2f 62 69  74 73 00 2f 75 73 72 2f  |x-gnu/bits./usr/|
# 000034b0  69 6e 63 6c 75 64 65 2f  69 33 38 36 2d 6c 69 6e  |include/i386-lin|
# 000034c0  75 78 2d 67 6e 75 2f 62  69 74 73 2f 74 79 70 65  |ux-gnu/bits/type|
# 000034d0  73 00 2f 75 73 72 2f 69  6e 63 6c 75 64 65 00 00  |s./usr/include..|
# 000034e0  68 65 6c 6c 6f 2e 63 00  01 00 00 73 74 64 64 65  |hello.c....stdde|
# 000034f0  66 2e 68 00 02 00 00 74  79 70 65 73 2e 68 00 03  |f.h....types.h..|
# 00003500  00 00 73 74 72 75 63 74  5f 46 49 4c 45 2e 68 00  |..struct_FILE.h.|
# 00003510  04 00 00 46 49 4c 45 2e  68 00 04 00 00 73 74 64  |...FILE.h....std|
# 00003520  69 6f 2e 68 00 05 00 00  73 79 73 5f 65 72 72 6c  |io.h....sys_errl|
# 00003530  69 73 74 2e 68 00 03 00  00 00 05 0c 00 05 02 99  |ist.h...........|
# 00003540  11 00 00 14 05 05 08 83  05 0c 08 3d 05 01 59 02  |...........=..Y.|
# 00003550  0a 00 01 01 5f 49 4f 5f  62 75 66 5f 65 6e 64 00  |...._IO_buf_end.|
# 00003560  2e 2f 64 65 6d 6f 2d 70  72 6f 67 72 61 6d 73 2f  |./demo-programs/|
# 00003570  68 65 6c 6c 6f 2e 63 00  5f 6f 6c 64 5f 6f 66 66  |hello.c._old_off|
# 00003580  73 65 74 00 73 79 73 5f  6e 65 72 72 00 5f 49 4f  |set.sys_nerr._IO|
# 00003590  5f 73 61 76 65 5f 65 6e  64 00 73 68 6f 72 74 20  |_save_end.short |
# 000035a0  69 6e 74 00 73 69 7a 65  5f 74 00 5f 66 72 65 65  |int.size_t._free|
# 000035b0  72 65 73 5f 6c 69 73 74  00 5f 49 4f 5f 77 72 69  |res_list._IO_wri|
# 000035c0  74 65 5f 70 74 72 00 5f  66 6c 61 67 73 00 5f 49  |te_ptr._flags._I|
# 000035d0  4f 5f 62 75 66 5f 62 61  73 65 00 5f 6d 61 72 6b  |O_buf_base._mark|
# 000035e0  65 72 73 00 5f 49 4f 5f  72 65 61 64 5f 65 6e 64  |ers._IO_read_end|
# 000035f0  00 5f 66 72 65 65 72 65  73 5f 62 75 66 00 73 74  |._freeres_buf.st|
# 00003600  64 65 72 72 00 6c 6f 6e  67 20 6c 6f 6e 67 20 69  |derr.long long i|
# 00003610  6e 74 00 5f 6c 6f 63 6b  00 5f 5f 69 6e 74 36 34  |nt._lock.__int64|
# 00003620  5f 74 00 5f 63 75 72 5f  63 6f 6c 75 6d 6e 00 47  |_t._cur_column.G|
# 00003630  4e 55 20 43 31 37 20 39  2e 32 2e 31 20 32 30 32  |NU C17 9.2.1 202|
# 00003640  30 30 31 32 33 20 2d 6d  74 75 6e 65 3d 67 65 6e  |00123 -mtune=gen|
# 00003650  65 72 69 63 20 2d 6d 61  72 63 68 3d 69 36 38 36  |eric -march=i686|
# 00003660  20 2d 67 20 2d 66 61 73  79 6e 63 68 72 6f 6e 6f  | -g -fasynchrono|
# 00003670  75 73 2d 75 6e 77 69 6e  64 2d 74 61 62 6c 65 73  |us-unwind-tables|
# 00003680  00 5f 49 4f 5f 46 49 4c  45 00 75 6e 73 69 67 6e  |._IO_FILE.unsign|
# 00003690  65 64 20 63 68 61 72 00  6c 6f 6e 67 20 6c 6f 6e  |ed char.long lon|
# 000036a0  67 20 75 6e 73 69 67 6e  65 64 20 69 6e 74 00 5f  |g unsigned int._|
# 000036b0  49 4f 5f 6d 61 72 6b 65  72 00 5f 73 68 6f 72 74  |IO_marker._short|
# 000036c0  62 75 66 00 5f 49 4f 5f  77 72 69 74 65 5f 62 61  |buf._IO_write_ba|
# 000036d0  73 65 00 5f 75 6e 75 73  65 64 32 00 5f 49 4f 5f  |se._unused2._IO_|
# 000036e0  72 65 61 64 5f 70 74 72  00 2f 72 6f 6f 74 2f 48  |read_ptr./root/H|
# 000036f0  61 63 6b 69 6e 67 4e 6f  74 65 62 6f 6f 6b 73 00  |ackingNotebooks.|
# 00003700  6d 61 69 6e 00 73 68 6f  72 74 20 75 6e 73 69 67  |main.short unsig|
# 00003710  6e 65 64 20 69 6e 74 00  5f 5f 70 61 64 35 00 5f  |ned int.__pad5._|
# 00003720  49 4f 5f 63 6f 64 65 63  76 74 00 5f 49 4f 5f 77  |IO_codecvt._IO_w|
# 00003730  72 69 74 65 5f 65 6e 64  00 5f 5f 6f 66 66 36 34  |rite_end.__off64|
# 00003740  5f 74 00 5f 5f 6f 66 66  5f 74 00 5f 63 68 61 69  |_t.__off_t._chai|
# 00003ee0  73 74 72 74 61 62 00 2e  73 68 73 74 72 74 61 62  |strtab..shstrtab|
# 00003ef0  00 2e 69 6e 74 65 72 70  00 2e 6e 6f 74 65 2e 67  |..interp..note.g|
# 00003f00  6e 75 2e 62 75 69 6c 64  2d 69 64 00 2e 6e 6f 74  |nu.build-id..not|
# 00003f10  65 2e 41 42 49 2d 74 61  67 00 2e 67 6e 75 2e 68  |e.ABI-tag..gnu.h|
# 00003f20  61 73 68 00 2e 64 79 6e  73 79 6d 00 2e 64 79 6e  |ash..dynsym..dyn|
# 00003f30  73 74 72 00 2e 67 6e 75  2e 76 65 72 73 69 6f 6e  |str..gnu.version|
# 00003f40  00 2e 67 6e 75 2e 76 65  72 73 69 6f 6e 5f 72 00  |..gnu.version_r.|
# 00003f50  2e 72 65 6c 2e 64 79 6e  00 2e 72 65 6c 2e 70 6c  |.rel.dyn..rel.pl|
# 00003f60  74 00 2e 69 6e 69 74 00  2e 70 6c 74 2e 67 6f 74  |t..init..plt.got|
# 00003f70  00 2e 74 65 78 74 00 2e  66 69 6e 69 00 2e 72 6f  |..text..fini..ro|
# 00003f80  64 61 74 61 00 2e 65 68  5f 66 72 61 6d 65 5f 68  |data..eh_frame_h|
# 00003f90  64 72 00 2e 65 68 5f 66  72 61 6d 65 00 2e 69 6e  |dr..eh_frame..in|
# 00003fa0  69 74 5f 61 72 72 61 79  00 2e 66 69 6e 69 5f 61  |it_array..fini_a|
# 00003fb0  72 72 61 79 00 2e 64 79  6e 61 6d 69 63 00 2e 67  |rray..dynamic..g|
# 00003fc0  6f 74 2e 70 6c 74 00 2e  64 61 74 61 00 2e 62 73  |ot.plt..data..bs|
# 00003fd0  73 00 2e 63 6f 6d 6d 65  6e 74 00 2e 64 65 62 75  |s..comment..debu|
# 00003fe0  67 5f 61 72 61 6e 67 65  73 00 2e 64 65 62 75 67  |g_aranges..debug|
# 00003ff0  5f 69 6e 66 6f 00 2e 64  65 62 75 67 5f 61 62 62  |_info..debug_abb|
# 00004000  72 65 76 00 2e 64 65 62  75 67 5f 6c 69 6e 65 00  |rev..debug_line.|
# 00004010  2e 64 65 62 75 67 5f 73  74 72 00 00 00 00 00 00  |.debug_str......|
# 00004020  00 00 00 00 00 00 00 00  00 00 00 00 00 00 00 00  |................|
# *
# 00004040  00 00 00 00 1b 00 00 00  01 00 00 00 02 00 00 00  |................|
# 00004050  94 01 00 00 94 01 00 00  13 00 00 00 00 00 00 00  |................|
# 00004060  00 00 00 00 01 00 00 00  00 00 00 00 23 00 00 00  |............#...|
# 00004070  07 00 00 00 02 00 00 00  a8 01 00 00 a8 01 00 00  |................|
# 00004080  24 00 00 00 00 00 00 00  00 00 00 00 04 00 00 00  |$...............|
# 00004090  00 00 00 00 36 00 00 00  07 00 00 00 02 00 00 00  |....6...........|
# 000040a0  cc 01 00 00 cc 01 00 00  20 00 00 00 00 00 00 00  |........ .......|
# 000040b0  00 00 00 00 04 00 00 00  00 00 00 00 44 00 00 00  |............D...|
# 000040c0  f6 ff ff 6f 02 00 00 00  ec 01 00 00 ec 01 00 00  |...o............|
# 000040d0  20 00 00 00 05 00 00 00  00 00 00 00 04 00 00 00  | ...............|
# 000040e0  04 00 00 00 4e 00 00 00  0b 00 00 00 02 00 00 00  |....N...........|
# 000040f0  0c 02 00 00 0c 02 00 00  80 00 00 00 06 00 00 00  |................|
# 00004100  01 00 00 00 04 00 00 00  10 00 00 00 56 00 00 00  |............V...|
# 00004110  03 00 00 00 02 00 00 00  8c 02 00 00 8c 02 00 00  |................|
# 00004120  9b 00 00 00 00 00 00 00  00 00 00 00 01 00 00 00  
00 00 00 00 00 00  00 00 00 00 01 00 00 00  |E...............|
# 00004590  00 00 00 00                                       |....|
# 00004594

# %% [markdown]
# ### let's compile memory_segments.c file and use it to examine various sections

# %%
# %%bash
# in=./demo-programs/memory_segments.c
# out=memory_segments.exe
#
# gcc -g -o $out $in
# ./$out
# Out:
# output from main function
# main is at address: 0x440257
# main is at address: 0x440257
# function is at address: 0x4401b9
# global_initialized_var is at address 0x443024
# static_initialized_var is at address 0x443038
#
# static_var is at address 0x443040
# global_var is at address 0x443044
#
# heap_var is at address 0x23b41a0
#
# stack_var is at address 0xbfa5a908
#
# calling function()...
# Output inside function:
# static_initialized_var = 15
# static_initialized_var is at address 0x443034
# stack_var = 100
# stack_var is at address 0xbfa5a8ec
#
# calling function() again...
# Output inside function:
# static_initialized_var = 25
# static_initialized_var is at address 0x443034
# stack_var = 100
# stack_var is at address 0xbfa5a8ec

# %%
# see the memory_segments.c source file
! cat ./demo-programs/memory_segments.c
# Out:
# #include <stdio.h>
# #include <stdlib.h>
#
# int global_var;
# int global_initialized_var = 5;
# char global_string[] = "John Smith!";
#
# void function() {
#    int stack_var = 100;
#    // notice this variable has the same name as the one in main()
#    static int static_initialized_var = 5;
#    static_initialized_var += 10;
#    printf("%s\n", "Output inside function:");
#    printf("static_initialized_var = %d\n", static_initialized_var);
#    printf("static_initialized_var is at address %p\n", &static_initialized_var);
#    printf("stack_var = %d\n", stack_var);
#    printf("stack_var is at address %p\n", &stack_var);
# }
#
#
# int main() {
#    int stack_var; // same name as the variable in function()
#    static int static_var;
#    int * heap_var_ptr;
#    static int static_initialized_var = 5;
#
#    heap_var_ptr = (int *) malloc(4);
#    printf("%s\n", "output from main function");
#    // these addressse are in the code/text segment
#    printf("main is at address: %p\n", main);
#    printf("main is at address: %p\n", &main);
#    printf("function is at address: %p\n", function);
#
#    // These variables are in the data segment
#    printf("global_initialized_var is at address %p\n", &global_initialized_var);
#    printf("static_initialized_var is at address %p\n\n", &static_initialized_var);
#
#    // These variables are in the bss segment
#    printf("static_var is at address %p\n", &static_var);
#    printf("global_var is at address %p\n\n", &global_var);
#
#    // This variable is in the heap segment
#    printf("heap_var is at address %p\n\n", heap_var_ptr);
#
#    // These variables are in the stack segment
#    printf("stack_var is at address %p\n", &stack_var);
#
#    printf("\ncalling function()...\n");
#    function();
#
#    // call function again
#    printf("\ncalling function() again...\n");
#    // what do you think is the values of static variable in function()?
#    function();
#    return 0;
# }

# %% [markdown]
# ## ELF file parts
#
# ## Symbols
# - function names, e.g., if printf built-in function is used, how does the program find it?
#
# ## Sections
# - symbols are organized into **sections** - code lives in one section (.text) and data lives in another (.data, .rodata)
#
# ## Segments
# - sections are organized into **segments**
#
# ## readelf and objdump
# - these utilities can help us look at various parts

# %% [markdown]
# ### look at all the symbols of a binary
# - import symbols: main, _start, puts

# %%
! readelf --symbols memory_segments.exe
# Out:
# Symbol table '.dynsym' contains 10 entries:
#    Num:    Value  Size Type    Bind   Vis      Ndx Name
#      0: 00000000     0 NOTYPE  LOCAL  DEFAULT  UND
#      1: 00000000     0 NOTYPE  WEAK   DEFAULT  UND _ITM_deregisterTMCloneTab
#      2: 00000000     0 FUNC    GLOBAL DEFAULT  UND printf@GLIBC_2.0 (2)
#      3: 00000000     0 FUNC    WEAK   DEFAULT  UND __cxa_finalize@GLIBC_2.1.3 (3)
#      4: 00000000     0 FUNC    GLOBAL DEFAULT  UND malloc@GLIBC_2.0 (2)
#      5: 00000000     0 FUNC    GLOBAL DEFAULT  UND puts@GLIBC_2.0 (2)
#      6: 00000000     0 NOTYPE  WEAK   DEFAULT  UND __gmon_start__
#      7: 00000000     0 FUNC    GLOBAL DEFAULT  UND __libc_start_main@GLIBC_2.0 (2)
#      8: 00000000     0 NOTYPE  WEAK   DEFAULT  UND _ITM_registerTMCloneTable
#      9: 00002004     4 OBJECT  GLOBAL DEFAULT   16 _IO_stdin_used
#
# Symbol table '.symtab' contains 81 entries:
#    Num:    Value  Size Type    Bind   Vis      Ndx Name
#      0: 00000000     0 NOTYPE  LOCAL  DEFAULT  UND
#      1: 00000194     0 SECTION LOCAL  DEFAULT    1
#      2: 000001a8     0 SECTION LOCAL  DEFAULT    2
#      3: 000001cc     0 SECTION LOCAL  DEFAULT    3
#      4: 000001ec     0 SECTION LOCAL  DEFAULT    4
#      5: 0000020c     0 SECTION LOCAL  DEFAULT    5
#      6: 000002ac     0 SECTION LOCAL  DEFAULT    6
#      7: 00000356     0 SECTION LOCAL  DEFAULT    7
#      8: 0000036c     0 SECTION LOCAL  DEFAULT    8
#      9: 0000039c     0 SECTION LOCAL  DEFAULT    9
#     10: 000003dc     0 SECTION LOCAL  DEFAULT   10
#     11: 00001000     0 SECTION LOCAL  DEFAULT   11
#     12: 00001020     0 SECTION LOCAL  DEFAULT   12
#     13: 00001070     0 SECTION LOCAL  DEFAULT   13
#     14: 00001080     0 SECTION LOCAL  DEFAULT   14
#     15: 00001418     0 SECTION LOCAL  DEFAULT   15
#     16: 00002000     0 SECTION LOCAL  DEFAULT   16
#     17: 000021c8     0 SECTION LOCAL  DEFAULT   17
#     18: 00002214     0 SECTION LOCAL  DEFAULT   18
#     19: 00003ef4     0 SECTION LOCAL  DEFAULT   19
#     20: 00003ef8     0 SECTION LOCAL  DEFAULT   20
#     21: 00003efc     0 SECTION LOCAL  DEFAULT   21
#     22: 00003fec     0 SECTION LOCAL  DEFAULT   22
#     23: 00004000     0 SECTION LOCAL  DEFAULT   23
#     24: 0000401c     0 SECTION LOCAL  DEFAULT   24
#     25: 00004030     0 SECTION LOCAL  DEFAULT   25
#     26: 00000000     0 SECTION LOCAL  DEFAULT   26
#     27: 00000000     0 SECTION LOCAL  DEFAULT   27
#     28: 00000000     0 SECTION LOCAL  DEFAULT   28
#     29: 00000000     0 SECTION LOCAL  DEFAULT   29
#     30: 00000000     0 SECTION LOCAL  DEFAULT   30
#     31: 00000000     0 SECTION LOCAL  DEFAULT   31
#     32: 00000000     0 FILE    LOCAL  DEFAULT  ABS crtstuff.c
#     33: 000010d0     0 FUNC    LOCAL  DEFAULT   14 deregister_tm_clones
#     34: 00001110     0 FUNC    LOCAL  DEFAULT   14 register_tm_clones
#     35: 00001160     0 FUNC    LOCAL  DEFAULT   14 __do_global_dtors_aux
#     36: 00004030     1 OBJECT  LOCAL  DEFAULT   25 completed.7003
#     37: 00003ef8     0 OBJECT  LOCAL  DEFAULT   20 __do_global_dtors_aux_fin
#     38: 000011b0     0 FUNC    LOCAL  DEFAULT   14 frame_dummy
#     39: 00003ef4     0 OBJECT  LOCAL  DEFAULT   19 __frame_dummy_init_array_
#     40: 00000000     0 FILE    LOCAL  DEFAULT  ABS memory_segments.c
#     41: 00004028     4 OBJECT  LOCAL  DEFAULT   24 static_initialized_var.24
#     42: 0000402c     4 OBJECT  LOCAL  DEFAULT   24 static_initialized_var.24
#     43: 00004034     4 OBJECT  LOCAL  DEFAULT   25 static_var.2426
#     44: 00000000     0 FILE    LOCAL  DEFAULT  ABS crtstuff.c
#     45: 00002360     0 OBJECT  LOCAL  DEFAULT   18 __FRAME_END__
#     46: 00000000     0 FILE    LOCAL  DEFAULT  ABS
#     47: 00003ef8     0 NOTYPE  LOCAL  DEFAULT   19 __init_array_end
#     48: 00003efc     0 OBJECT  LOCAL  DEFAULT   21 _DYNAMIC
#     49: 00003ef4     0 NOTYPE  LOCAL  DEFAULT   19 __init_array_start
#     50: 000021c8     0 NOTYPE  LOCAL  DEFAULT   17 __GNU_EH_FRAME_HDR
#     51: 00004000     0 OBJECT  LOCAL  DEFAULT   23 _GLOBAL_OFFSET_TABLE_
#     52: 00001000     0 FUNC    LOCAL  DEFAULT   11 _init
#     53: 00001410     1 FUNC    GLOBAL DEFAULT   14 __libc_csu_fini
#     54: 00000000     0 NOTYPE  WEAK   DEFAULT  UND _ITM_deregisterTMCloneTab
#     55: 000010c0     4 FUNC    GLOBAL HIDDEN    14 __x86.get_pc_thunk.bx
#     56: 0000401c     0 NOTYPE  WEAK   DEFAULT   24 data_start
#     57: 00000000     0 FUNC    GLOBAL DEFAULT  UND printf@@GLIBC_2.0
#     58: 00001411     0 FUNC    GLOBAL HIDDEN    14 __x86.get_pc_thunk.bp
#     59: 00004030     0 NOTYPE  GLOBAL DEFAULT   24 _edata
#     60: 00001418     0 FUNC    GLOBAL HIDDEN    15 _fini
#     61: 000011b5     0 FUNC    GLOBAL HIDDEN    14 __x86.get_pc_thunk.dx
#     62: 00000000     0 FUNC    WEAK   DEFAULT  UND __cxa_finalize@@GLIBC_2.1
#     63: 00004038     4 OBJECT  GLOBAL DEFAULT   25 global_var
#     64: 00000000     0 FUNC    GLOBAL DEFAULT  UND malloc@@GLIBC_2.0
#     65: 0000401c     0 NOTYPE  GLOBAL DEFAULT   24 __data_start
#     66: 00000000     0 FUNC    GLOBAL DEFAULT  UND puts@@GLIBC_2.0
#     67: 00000000     0 NOTYPE  WEAK   DEFAULT  UND __gmon_start__
#     68: 00004020     0 OBJECT  GLOBAL HIDDEN    24 __dso_handle
#     69: 00002004     4 OBJECT  GLOBAL DEFAULT   16 _IO_stdin_used
#     70: 00000000     0 FUNC    GLOBAL DEFAULT  UND __libc_start_main@@GLIBC_
#     71: 000013b0    93 FUNC    GLOBAL DEFAULT   14 __libc_csu_init
#     72: 0000403c     0 NOTYPE  GLOBAL DEFAULT   25 _end
#     73: 00001080    54 FUNC    GLOBAL DEFAULT   14 _start
#     74: 00002000     4 OBJECT  GLOBAL DEFAULT   16 _fp_hw
#     75: 00004030     0 NOTYPE  GLOBAL DEFAULT   25 __bss_start
#     76: 00001257   342 FUNC    GLOBAL DEFAULT   14 main
#     77: 000011b9   158 FUNC    GLOBAL DEFAULT   14 function
#     78: 00004024     4 OBJECT  GLOBAL DEFAULT   24 global_initialized_var
#     79: 00004030     0 OBJECT  GLOBAL HIDDEN    24 __TMC_END__
#     80: 00000000     0 NOTYPE  WEAK   DEFAULT  UND _ITM_registerTMCloneTable

# %% [markdown]
# ### display all the sections
# - some important sections .text, .rodata, .data, .bss

# %%
! readelf --sections memory_segments.exe
# Out:
# There are 35 section headers, starting at offset 0x4310:
#
# Section Headers:
#   [Nr] Name              Type            Addr     Off    Size   ES Flg Lk Inf Al
#   [ 0]                   NULL            00000000 000000 000000 00      0   0  0
#   [ 1] .interp           PROGBITS        00000194 000194 000013 00   A  0   0  1
#   [ 2] .note.gnu.build-i NOTE            000001a8 0001a8 000024 00   A  0   0  4
#   [ 3] .note.ABI-tag     NOTE            000001cc 0001cc 000020 00   A  0   0  4
#   [ 4] .gnu.hash         GNU_HASH        000001ec 0001ec 000020 04   A  5   0  4
#   [ 5] .dynsym           DYNSYM          0000020c 00020c 0000a0 10   A  6   1  4
#   [ 6] .dynstr           STRTAB          000002ac 0002ac 0000a9 00   A  0   0  1
#   [ 7] .gnu.version      VERSYM          00000356 000356 000014 02   A  5   0  2
#   [ 8] .gnu.version_r    VERNEED         0000036c 00036c 000030 00   A  6   1  4
#   [ 9] .rel.dyn          REL             0000039c 00039c 000040 08   A  5   0  4
#   [10] .rel.plt          REL             000003dc 0003dc 000020 08  AI  5  23  4
#   [11] .init             PROGBITS        00001000 001000 000020 00  AX  0   0  4
#   [12] .plt              PROGBITS        00001020 001020 000050 04  AX  0   0 16
#   [13] .plt.got          PROGBITS        00001070 001070 000008 08  AX  0   0  8
#   [14] .text             PROGBITS        00001080 001080 000395 00  AX  0   0 16
#   [15] .fini             PROGBITS        00001418 001418 000014 00  AX  0   0  4
#   [16] .rodata           PROGBITS        00002000 002000 0001c5 00   A  0   0  4
#   [17] .eh_frame_hdr     PROGBITS        000021c8 0021c8 00004c 00   A  0   0  4
#   [18] .eh_frame         PROGBITS        00002214 002214 000150 00   A  0   0  4
#   [19] .init_array       INIT_ARRAY      00003ef4 002ef4 000004 04  WA  0   0  4
#   [20] .fini_array       FINI_ARRAY      00003ef8 002ef8 000004 04  WA  0   0  4
#   [21] .dynamic          DYNAMIC         00003efc 002efc 0000f0 08  WA  6   0  4
#   [22] .got              PROGBITS        00003fec 002fec 000014 04  WA  0   0  4
#   [23] .got.plt          PROGBITS        00004000 003000 00001c 04  WA  0   0  4
#   [24] .data             PROGBITS        0000401c 00301c 000020 00  WA  0   0  4
#   [25] .bss              NOBITS          0000403c 00303c 00000c 00  WA  0   0  4
#   [26] .comment          PROGBITS        00000000 00303c 000026 01  MS  0   0  1
#   [27] .debug_aranges    PROGBITS        00000000 003062 000020 00      0   0  1
#   [28] .debug_info       PROGBITS        00000000 003082 0003d2 00      0   0  1
#   [29] .debug_abbrev     PROGBITS        00000000 003454 00010a 00      0   0  1
#   [30] .debug_line       PROGBITS        00000000 00355e 000159 00      0   0  1
#   [31] .debug_str        PROGBITS        00000000 0036b7 0002fd 01  MS  0   0  1
#   [32] .symtab           SYMTAB          00000000 0039b4 000520 10     33  53  4
#   [33] .strtab           STRTAB          00000000 003ed4 0002f7 00      0   0  1
#   [34] .shstrtab         STRTAB          00000000 0041cb 000145 00      0   0  1
# Key to Flags:
#   W (write), A (alloc), X (execute), M (merge), S (strings), I (info),
#   L (link order), O (extra OS processing required), G (group), T (TLS),
#   C (compressed), x (unknown), o (OS specific), E (exclude),
#   p (processor specific)

# %% [markdown]
# ## look at just one section, e.g., .rodata
# - some read-only data is stored in .rodata, e.g. Hello World!

# %%
! readelf -x .rodata memory_segments.exe
# Out:
# Hex dump of section '.rodata':
#   0x00002000 03000000 01000200 4f757470 75742069 ........Output i
#   0x00002010 6e736964 65206675 6e637469 6f6e3a00 nside function:.
#   0x00002020 73746174 69635f69 6e697469 616c697a static_initializ
#   0x00002030 65645f76 6172203d 2025640a 00000000 ed_var = %d.....
#   0x00002040 73746174 69635f69 6e697469 616c697a static_initializ
#   0x00002050 65645f76 61722069 73206174 20616464 ed_var is at add
#   0x00002060 72657373 2025700a 00737461 636b5f76 ress %p..stack_v
#   0x00002070 6172203d 2025640a 00737461 636b5f76 ar = %d..stack_v
#   0x00002080 61722069 73206174 20616464 72657373 ar is at address
#   0x00002090 2025700a 006f7574 70757420 66726f6d  %p..output from
#   0x000020a0 206d6169 6e206675 6e637469 6f6e006d  main function.m
#   0x000020b0 61696e20 69732061 74206164 64726573 ain is at addres
#   0x000020c0 733a2025 700a0066 756e6374 696f6e20 s: %p..function
#   0x000020d0 69732061 74206164 64726573 733a2025 is at address: %
#   0x000020e0 700a0000 676c6f62 616c5f69 6e697469 p...global_initi
#   0x000020f0 616c697a 65645f76 61722069 73206174 alized_var is at
#   0x00002100 20616464 72657373 2025700a 00000000  address %p.....
#   0x00002110 73746174 69635f69 6e697469 616c697a static_initializ
#   0x00002120 65645f76 61722069 73206174 20616464 ed_var is at add
#   0x00002130 72657373 2025700a 0a007374 61746963 ress %p...static
#   0x00002140 5f766172 20697320 61742061 64647265 _var is at addre
#   0x00002150 73732025 700a0067 6c6f6261 6c5f7661 ss %p..global_va
#   0x00002160 72206973 20617420 61646472 65737320 r is at address
#   0x00002170 25700a0a 00686561 705f7661 72206973 %p...heap_var is
#   0x00002180 20617420 61646472 65737320 25700a0a  at address %p..
#   0x00002190 000a6361 6c6c696e 67206675 6e637469 ..calling functi
#   0x000021a0 6f6e2829 2e2e2e00 0a63616c 6c696e67 on().....calling
#   0x000021b0 2066756e 6374696f 6e282920 61676169  function() agai
#   0x000021c0 6e2e2e2e 00                         n....

# %% [markdown]
# ### objdump program can also be used to examine each program sections

# %%
! objdump -s -j .rodata memory_segments.exe
# Out:
# memory_segments.exe:     file format elf32-i386
#
# Contents of section .rodata:
#  2000 03000000 01000200 4f757470 75742069  ........Output i
#  2010 6e736964 65206675 6e637469 6f6e3a00  nside function:.
#  2020 73746174 69635f69 6e697469 616c697a  static_initializ
#  2030 65645f76 6172203d 2025640a 00000000  ed_var = %d.....
#  2040 73746174 69635f69 6e697469 616c697a  static_initializ
#  2050 65645f76 61722069 73206174 20616464  ed_var is at add
#  2060 72657373 2025700a 00737461 636b5f76  ress %p..stack_v
#  2070 6172203d 2025640a 00737461 636b5f76  ar = %d..stack_v
#  2080 61722069 73206174 20616464 72657373  ar is at address
#  2090 2025700a 006f7574 70757420 66726f6d   %p..output from
#  20a0 206d6169 6e206675 6e637469 6f6e006d   main function.m
#  20b0 61696e20 69732061 74206164 64726573  ain is at addres
#  20c0 733a2025 700a0066 756e6374 696f6e20  s: %p..function
#  20d0 69732061 74206164 64726573 733a2025  is at address: %
#  20e0 700a0000 676c6f62 616c5f69 6e697469  p...global_initi
#  20f0 616c697a 65645f76 61722069 73206174  alized_var is at
#  2100 20616464 72657373 2025700a 00000000   address %p.....
#  2110 73746174 69635f69 6e697469 616c697a  static_initializ
#  2120 65645f76 61722069 73206174 20616464  ed_var is at add
#  2130 72657373 2025700a 0a007374 61746963  ress %p...static
#  2140 5f766172 20697320 61742061 64647265  _var is at addre
#  2150 73732025 700a0067 6c6f6261 6c5f7661  ss %p..global_va
#  2160 72206973 20617420 61646472 65737320  r is at address
#  2170 25700a0a 00686561 705f7661 72206973  %p...heap_var is
#  2180 20617420 61646472 65737320 25700a0a   at address %p..
#  2190 000a6361 6c6c696e 67206675 6e637469  ..calling functi
#  21a0 6f6e2829 2e2e2e00 0a63616c 6c696e67  on().....calling
#  21b0 2066756e 6374696f 6e282920 61676169   function() agai
#  21c0 6e2e2e2e 00                          n....

# %%
! readelf -x .data memory_segments.exe
# even though global_initialized_var = 5; we see in hex but not ascii
# Out:
# Hex dump of section '.data':
#   0x0000401c 00000000 20400000 05000000 4a6f686e .... @......John
#   0x0000402c 20536d69 74682100 05000000 05000000  Smith!.........

# %%
! readelf -x .bss memory_segments.exe
# Out:
# Section '.bss' has no data to dump.

# %% [markdown]
# ### look at the segments
# - GNU_STACK is important to note
#     - RW - Read and Write; NO Execute
#     - data in stack will be treated as literal values or just data but not code!

# %%
! readelf --segments hello
# Out:
# Elf file type is DYN (Shared object file)
# Entry point 0x1080
# There are 11 program headers, starting at offset 52
#
# Program Headers:
#   Type           Offset   VirtAddr   PhysAddr   FileSiz MemSiz  Flg Align
#   PHDR           0x000034 0x00000034 0x00000034 0x00160 0x00160 R   0x4
#   INTERP         0x000194 0x00000194 0x00000194 0x00013 0x00013 R   0x1
#       [Requesting program interpreter: /lib/ld-linux.so.2]
#   LOAD           0x000000 0x00000000 0x00000000 0x003fc 0x003fc R   0x1000
#   LOAD           0x001000 0x00001000 0x00001000 0x0042c 0x0042c R E 0x1000
#   LOAD           0x002000 0x00002000 0x00002000 0x00364 0x00364 R   0x1000
#   LOAD           0x002ef4 0x00003ef4 0x00003ef4 0x0013c 0x00148 RW  0x1000
#   DYNAMIC        0x002efc 0x00003efc 0x00003efc 0x000f0 0x000f0 RW  0x4
#   NOTE           0x0001a8 0x000001a8 0x000001a8 0x00044 0x00044 R   0x4
#   GNU_EH_FRAME   0x0021c8 0x000021c8 0x000021c8 0x0004c 0x0004c R   0x4
#   GNU_STACK      0x000000 0x00000000 0x00000000 0x00000 0x00000 RW  0x10
#   GNU_RELRO      0x002ef4 0x00003ef4 0x00003ef4 0x0010c 0x0010c R   0x1
#
#  Section to Segment mapping:
#   Segment Sections...
#    00
#    01     .interp
#    02     .interp .note.gnu.build-id .note.ABI-tag .gnu.hash .dynsym .dynstr .gnu.version .gnu.version_r .rel.dyn .rel.plt
#    03     .init .plt .plt.got .text .fini
#    04     .rodata .eh_frame_hdr .eh_frame
#    05     .init_array .fini_array .dynamic .got .got.plt .data .bss
#    06     .dynamic
#    07     .note.gnu.build-id .note.ABI-tag
#    08     .eh_frame_hdr
#    09
#    10     .init_array .fini_array .dynamic .got

# %% [markdown]
# ## Disasseble using objdump
# - look at assembly of the whole binary
# - by default show AT&T assembly syntax with %, $
#     - source before the destination
#     - e.g., `mov $5, %eax`
# - https://en.wikipedia.org/wiki/X86_assembly_language

# %%
! objdump -d hello
# Out:
# hello:     file format elf32-i386
#
#
# Disassembly of section .init:
#
# 00001000 <_init>:
#     1000:	53                   	push   %ebx
#     1001:	83 ec 08             	sub    $0x8,%esp
#     1004:	e8 97 00 00 00       	call   10a0 <__x86.get_pc_thunk.bx>
#     1009:	81 c3 f7 2f 00 00    	add    $0x2ff7,%ebx
#     100f:	8b 83 f4 ff ff ff    	mov    -0xc(%ebx),%eax
#     1015:	85 c0                	test   %eax,%eax
#     1017:	74 02                	je     101b <_init+0x1b>
#     1019:	ff d0                	call   *%eax
#     101b:	83 c4 08             	add    $0x8,%esp
#     101e:	5b                   	pop    %ebx
#     101f:	c3                   	ret
#
# Disassembly of section .plt:
#
# 00001020 <.plt>:
#     1020:	ff b3 04 00 00 00    	pushl  0x4(%ebx)
#     1026:	ff a3 08 00 00 00    	jmp    *0x8(%ebx)
#     102c:	00 00                	add    %al,(%eax)
# 	...
#
# 00001030 <puts@plt>:
#     1030:	ff a3 0c 00 00 00    	jmp    *0xc(%ebx)
#     1036:	68 00 00 00 00       	push   $0x0
#     103b:	e9 e0 ff ff ff       	jmp    1020 <.plt>
#
# 00001040 <__libc_start_main@plt>:
#     1040:	ff a3 10 00 00 00    	jmp    *0x10(%ebx)
#     1046:	68 08 00 00 00       	push   $0x8
#     104b:	e9 d0 ff ff ff       	jmp    1020 <.plt>
#
# Disassembly of section .plt.got:
#
# 00001050 <__cxa_finalize@plt>:
#     1050:	ff a3 f0 ff ff ff    	jmp    *-0x10(%ebx)
#     1056:	66 90                	xchg   %ax,%ax
#
# Disassembly of section .text:
#
# 00001060 <_start>:
#     1060:	31 ed                	xor    %ebp,%ebp
#     1062:	5e                   	pop    %esi
#     1063:	89 e1                	mov    %esp,%ecx
#     1065:	83 e4 f0             	and    $0xfffffff0,%esp
#     1068:	50                   	push   %eax
#     1069:	54                   	push   %esp
#     106a:	52                   	push   %edx
#     106b:	e8 22 00 00 00       	call   1092 <_start+0x32>
#     1070:	81 c3 90 2f 00 00    	add    $0x2f90,%ebx
#     1076:	8d 83 40 d2 ff ff    	lea    -0x2dc0(%ebx),%eax
#     107c:	50                   	push   %eax
#     107d:	8d 83 e0 d1 ff ff    	lea    -0x2e20(%ebx),%eax
#     1083:	50                   	push   %eax
#     1084:	51                   	push   %ecx
#     1085:	56                   	push   %esi
#     1086:	ff b3 f8 ff ff ff    	pushl  -0x8(%ebx)
#     108c:	e8 af ff ff ff       	call   1040 <__libc_start_main@plt>
#     1091:	f4                   	hlt
#     1092:	8b 1c 24             	mov    (%esp),%ebx
#     1095:	c3                   	ret
#     1096:	66 90                	xchg   %ax,%ax
#     1098:	66 90                	xchg   %ax,%ax
#     109a:	66 90                	xchg   %ax,%ax
#     109c:	66 90                	xchg   %ax,%ax
#     109e:	66 90                	xchg   %ax,%ax
#
# 000010a0 <__x86.get_pc_thunk.bx>:
#     10a0:	8b 1c 24             	mov    (%esp),%ebx
#     10a3:	c3                   	ret
#     10a4:	66 90                	xchg   %ax,%ax
#     10a6:	66 90                	xchg   %ax,%ax
#     10a8:	66 90                	xchg   %ax,%ax
#     10aa:	66 90                	xchg   %ax,%ax
#     10ac:	66 90                	xchg   %ax,%ax
#     10ae:	66 90                	xchg   %ax,%ax
#
# 000010b0 <deregister_tm_clones>:
#     10b0:	e8 e0 00 00 00       	call   1195 <__x86.get_pc_thunk.dx>
#     10b5:	81 c2 4b 2f 00 00    	add    $0x2f4b,%edx
#     10bb:	8d 8a 1c 00 00 00    	lea    0x1c(%edx),%ecx
#     10c1:	8d 82 1c 00 00 00    	lea    0x1c(%edx),%eax
#     10c7:	39 c8                	cmp    %ecx,%eax
#     10c9:	74 1d                	je     10e8 <deregister_tm_clones+0x38>
#     10cb:	8b 82 ec ff ff ff    	mov    -0x14(%edx),%eax
#     10d1:	85 c0                	test   %eax,%eax
#     10d3:	74 13                	je     10e8 <deregister_tm_clones+0x38>
#     10d5:	55                   	push   %ebp
#     10d6:	89 e5                	mov    %esp,%ebp
#     10d8:	83 ec 14             	sub    $0x14,%esp
#     10db:	51                   	push   %ecx
#     10dc:	ff d0                	call   *%eax
#     10de:	83 c4 10             	add    $0x10,%esp
#     10e1:	c9                   	leave
#     10e2:	c3                   	ret
#     10e3:	8d 74 26 00          	lea    0x0(%esi,%eiz,1),%esi
#     10e7:	90                   	nop
#     10e8:	c3                   	ret
#     10e9:	8d b4 26 00 00 00 00 	lea    0x0(%esi,%eiz,1),%esi
#
# 000010f0 <register_tm_clones>:
#     10f0:	e8 a0 00 00 00       	call   1195 <__x86.get_pc_thunk.dx>
#     10f5:	81 c2 0b 2f 00 00    	add    $0x2f0b,%edx
#     10fb:	55                   	push   %ebp
#     10fc:	89 e5                	mov    %esp,%ebp
#     10fe:	53                   	push   %ebx
#     10ff:	8d 8a 1c 00 00 00    	lea    0x1c(%edx),%ecx
#     1105:	8d 82 1c 00 00 00    	lea    0x1c(%edx),%eax
#     110b:	83 ec 04             	sub    $0x4,%esp
#     110e:	29 c8                	sub    %ecx,%eax
#     1110:	89 c3                	mov    %eax,%ebx
#     1112:	c1 e8 1f             	shr    $0x1f,%eax
#     1115:	c1 fb 02             	sar    $0x2,%ebx
#     1118:	01 d8                	add    %ebx,%eax
#     111a:	d1 f8                	sar    %eax
#     111c:	74 14                	je     1132 <register_tm_clones+0x42>
#     111e:	8b 92 fc ff ff ff    	mov    -0x4(%edx),%edx
#     1124:	85 d2                	test   %edx,%edx
#     1126:	74 0a                	je     1132 <register_tm_clones+0x42>
#     1128:	83 ec 08             	sub    $0x8,%esp
#     112b:	50                   	push   %eax
#     112c:	51                   	push   %ecx
#     112d:	ff d2                	call   *%edx
#     112f:	83 c4 10             	add    $0x10,%esp
#     1132:	8b 5d fc             	mov    -0x4(%ebp),%ebx
#     1135:	c9                   	leave
#     1136:	c3                   	ret
#     1137:	8d b4 26 00 00 00 00 	lea    0x0(%esi,%eiz,1),%esi
#     113e:	66 90                	xchg   %ax,%ax
#
# 00001140 <__do_global_dtors_aux>:
#     1140:	55                   	push   %ebp
#     1141:	89 e5                	mov    %esp,%ebp
#     1143:	53                   	push   %ebx
#     1144:	e8 57 ff ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     1149:	81 c3 b7 2e 00 00    	add    $0x2eb7,%ebx
#     114f:	83 ec 04             	sub    $0x4,%esp
#     1152:	80 bb 1c 00 00 00 00 	cmpb   $0x0,0x1c(%ebx)
#     1159:	75 27                	jne    1182 <__do_global_dtors_aux+0x42>
#     115b:	8b 83 f0 ff ff ff    	mov    -0x10(%ebx),%eax
#     1161:	85 c0                	test   %eax,%eax
#     1163:	74 11                	je     1176 <__do_global_dtors_aux+0x36>
#     1165:	83 ec 0c             	sub    $0xc,%esp
#     1168:	ff b3 18 00 00 00    	pushl  0x18(%ebx)
#     116e:	e8 dd fe ff ff       	call   1050 <__cxa_finalize@plt>
#     1173:	83 c4 10             	add    $0x10,%esp
#     1176:	e8 35 ff ff ff       	call   10b0 <deregister_tm_clones>
#     117b:	c6 83 1c 00 00 00 01 	movb   $0x1,0x1c(%ebx)
#     1182:	8b 5d fc             	mov    -0x4(%ebp),%ebx
#     1185:	c9                   	leave
#     1186:	c3                   	ret
#     1187:	8d b4 26 00 00 00 00 	lea    0x0(%esi,%eiz,1),%esi
#     118e:	66 90                	xchg   %ax,%ax
#
# 00001190 <frame_dummy>:
#     1190:	e9 5b ff ff ff       	jmp    10f0 <register_tm_clones>
#
# 00001195 <__x86.get_pc_thunk.dx>:
#     1195:	8b 14 24             	mov    (%esp),%edx
#     1198:	c3                   	ret
#
# 00001199 <main>:
#     1199:	8d 4c 24 04          	lea    0x4(%esp),%ecx
#     119d:	83 e4 f0             	and    $0xfffffff0,%esp
#     11a0:	ff 71 fc             	pushl  -0x4(%ecx)
#     11a3:	55                   	push   %ebp
#     11a4:	89 e5                	mov    %esp,%ebp
#     11a6:	53                   	push   %ebx
#     11a7:	51                   	push   %ecx
#     11a8:	e8 28 00 00 00       	call   11d5 <__x86.get_pc_thunk.ax>
#     11ad:	05 53 2e 00 00       	add    $0x2e53,%eax
#     11b2:	83 ec 0c             	sub    $0xc,%esp
#     11b5:	8d 90 08 e0 ff ff    	lea    -0x1ff8(%eax),%edx
#     11bb:	52                   	push   %edx
#     11bc:	89 c3                	mov    %eax,%ebx
#     11be:	e8 6d fe ff ff       	call   1030 <puts@plt>
#     11c3:	83 c4 10             	add    $0x10,%esp
#     11c6:	b8 00 00 00 00       	mov    $0x0,%eax
#     11cb:	8d 65 f8             	lea    -0x8(%ebp),%esp
#     11ce:	59                   	pop    %ecx
#     11cf:	5b                   	pop    %ebx
#     11d0:	5d                   	pop    %ebp
#     11d1:	8d 61 fc             	lea    -0x4(%ecx),%esp
#     11d4:	c3                   	ret
#
# 000011d5 <__x86.get_pc_thunk.ax>:
#     11d5:	8b 04 24             	mov    (%esp),%eax
#     11d8:	c3                   	ret
#     11d9:	66 90                	xchg   %ax,%ax
#     11db:	66 90                	xchg   %ax,%ax
#     11dd:	66 90                	xchg   %ax,%ax
#     11df:	90                   	nop
#
# 000011e0 <__libc_csu_init>:
#     11e0:	55                   	push   %ebp
#     11e1:	e8 5b 00 00 00       	call   1241 <__x86.get_pc_thunk.bp>
#     11e6:	81 c5 1a 2e 00 00    	add    $0x2e1a,%ebp
#     11ec:	57                   	push   %edi
#     11ed:	56                   	push   %esi
#     11ee:	53                   	push   %ebx
#     11ef:	83 ec 0c             	sub    $0xc,%esp
#     11f2:	89 eb                	mov    %ebp,%ebx
#     11f4:	8b 7c 24 28          	mov    0x28(%esp),%edi
#     11f8:	e8 03 fe ff ff       	call   1000 <_init>
#     11fd:	8d 9d f8 fe ff ff    	lea    -0x108(%ebp),%ebx
#     1203:	8d 85 f4 fe ff ff    	lea    -0x10c(%ebp),%eax
#     1209:	29 c3                	sub    %eax,%ebx
#     120b:	c1 fb 02             	sar    $0x2,%ebx
#     120e:	74 25                	je     1235 <__libc_csu_init+0x55>
#     1210:	31 f6                	xor    %esi,%esi
#     1212:	8d b6 00 00 00 00    	lea    0x0(%esi),%esi
#     1218:	83 ec 04             	sub    $0x4,%esp
#     121b:	57                   	push   %edi
#     121c:	ff 74 24 2c          	pushl  0x2c(%esp)
#     1220:	ff 74 24 2c          	pushl  0x2c(%esp)
#     1224:	ff 94 b5 f4 fe ff ff 	call   *-0x10c(%ebp,%esi,4)
#     122b:	83 c6 01             	add    $0x1,%esi
#     122e:	83 c4 10             	add    $0x10,%esp
#     1231:	39 f3                	cmp    %esi,%ebx
#     1233:	75 e3                	jne    1218 <__libc_csu_init+0x38>
#     1235:	83 c4 0c             	add    $0xc,%esp
#     1238:	5b                   	pop    %ebx
#     1239:	5e                   	pop    %esi
#     123a:	5f                   	pop    %edi
#     123b:	5d                   	pop    %ebp
#     123c:	c3                   	ret
#     123d:	8d 76 00             	lea    0x0(%esi),%esi
#
# 00001240 <__libc_csu_fini>:
#     1240:	c3                   	ret
#
# 00001241 <__x86.get_pc_thunk.bp>:
#     1241:	8b 2c 24             	mov    (%esp),%ebp
#     1244:	c3                   	ret
#
# Disassembly of section .fini:
#
# 00001248 <_fini>:
#     1248:	53                   	push   %ebx
#     1249:	83 ec 08             	sub    $0x8,%esp
#     124c:	e8 4f fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     1251:	81 c3 af 2d 00 00    	add    $0x2daf,%ebx
#     1257:	83 c4 08             	add    $0x8,%esp
#     125a:	5b                   	pop    %ebx
#     125b:	c3                   	ret

# %%
! objdump -D hello | grep -A20 main.:
# Out:
# 00001199 <main>:
#     1199:	8d 4c 24 04          	lea    0x4(%esp),%ecx
#     119d:	83 e4 f0             	and    $0xfffffff0,%esp
#     11a0:	ff 71 fc             	pushl  -0x4(%ecx)
#     11a3:	55                   	push   %ebp
#     11a4:	89 e5                	mov    %esp,%ebp
#     11a6:	53                   	push   %ebx
#     11a7:	51                   	push   %ecx
#     11a8:	e8 28 00 00 00       	call   11d5 <__x86.get_pc_thunk.ax>
#     11ad:	05 53 2e 00 00       	add    $0x2e53,%eax
#     11b2:	83 ec 0c             	sub    $0xc,%esp
#     11b5:	8d 90 08 e0 ff ff    	lea    -0x1ff8(%eax),%edx
#     11bb:	52                   	push   %edx
#     11bc:	89 c3                	mov    %eax,%ebx
#     11be:	e8 6d fe ff ff       	call   1030 <puts@plt>
#     11c3:	83 c4 10             	add    $0x10,%esp
#     11c6:	b8 00 00 00 00       	mov    $0x0,%eax
#     11cb:	8d 65 f8             	lea    -0x8(%ebp),%esp
#     11ce:	59                   	pop    %ecx
#     11cf:	5b                   	pop    %ebx
#     11d0:	5d                   	pop    %ebp

# %% [markdown]
# ### disassemble in Intel syntax
# - much cleaner
# - destination before source
#     - e.g., `mov eax, 5`

# %%
! objdump -M intel -D hello
# Out:
# hello:     file format elf32-i386
#
#
# Disassembly of section .interp:
#
# 00000194 <.interp>:
#  194:	2f                   	das
#  195:	6c                   	ins    BYTE PTR es:[edi],dx
#  196:	69 62 2f 6c 64 2d 6c 	imul   esp,DWORD PTR [edx+0x2f],0x6c2d646c
#  19d:	69 6e 75 78 2e 73 6f 	imul   ebp,DWORD PTR [esi+0x75],0x6f732e78
#  1a4:	2e 32 00             	xor    al,BYTE PTR cs:[eax]
#
# Disassembly of section .note.gnu.build-id:
#
# 000001a8 <.note.gnu.build-id>:
#  1a8:	04 00                	add    al,0x0
#  1aa:	00 00                	add    BYTE PTR [eax],al
#  1ac:	14 00                	adc    al,0x0
#  1ae:	00 00                	add    BYTE PTR [eax],al
#  1b0:	03 00                	add    eax,DWORD PTR [eax]
#  1b2:	00 00                	add    BYTE PTR [eax],al
#  1b4:	47                   	inc    edi
#  1b5:	4e                   	dec    esi
#  1b6:	55                   	push   ebp
#  1b7:	00 79 ff             	add    BYTE PTR [ecx-0x1],bh
#  1ba:	d1 94 05 ea 96 16 8c 	rcl    DWORD PTR [ebp+eax*1-0x73e96916],1
#  1c1:	9a 49 fd f3 3d 5d ac 	call   0xac5d:0x3df3fd49
#  1c8:	5c                   	pop    esp
#  1c9:	d7                   	xlat   BYTE PTR ds:[ebx]
#  1ca:	3f                   	aas
#  1cb:	94                   	xchg   esp,eax
#
# Disassembly of section .note.ABI-tag:
#
# 000001cc <.note.ABI-tag>:
#  1cc:	04 00                	add    al,0x0
#  1ce:	00 00                	add    BYTE PTR [eax],al
#  1d0:	10 00                	adc    BYTE PTR [eax],al
#  1d2:	00 00                	add    BYTE PTR [eax],al
#  1d4:	01 00                	add    DWORD PTR [eax],eax
#  1d6:	00 00                	add    BYTE PTR [eax],al
#  1d8:	47                   	inc    edi
#  1d9:	4e                   	dec    esi
#  1da:	55                   	push   ebp
#  1db:	00 00                	add    BYTE PTR [eax],al
#  1dd:	00 00                	add    BYTE PTR [eax],al
#  1df:	00 03                	add    BYTE PTR [ebx],al
#  1e1:	00 00                	add    BYTE PTR [eax],al
#  1e3:	00 02                	add    BYTE PTR [edx],al
#  1e5:	00 00                	add    BYTE PTR [eax],al
#  1e7:	00 00                	add    BYTE PTR [eax],al
#  1e9:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .gnu.hash:
#
# 000001ec <.gnu.hash>:
#  1ec:	02 00                	add    al,BYTE PTR [eax]
#  1ee:	00 00                	add    BYTE PTR [eax],al
#  1f0:	07                   	pop    es
#  1f1:	00 00                	add    BYTE PTR [eax],al
#  1f3:	00 01                	add    BYTE PTR [ecx],al
#  1f5:	00 00                	add    BYTE PTR [eax],al
#  1f7:	00 05 00 00 00 00    	add    BYTE PTR ds:0x0,al
#  1fd:	20 00                	and    BYTE PTR [eax],al
#  1ff:	20 00                	and    BYTE PTR [eax],al
#  201:	00 00                	add    BYTE PTR [eax],al
#  203:	00 07                	add    BYTE PTR [edi],al
#  205:	00 00                	add    BYTE PTR [eax],al
#  207:	00                   	.byte 0x0
#  208:	ad                   	lods   eax,DWORD PTR ds:[esi]
#  209:	4b                   	dec    ebx
#  20a:	e3 c0                	jecxz  1cc <_init-0xe34>
#
# Disassembly of section .dynsym:
#
# 0000020c <.dynsym>:
# 	...
#  21c:	56                   	push   esi
# 	...
#  225:	00 00                	add    BYTE PTR [eax],al
#  227:	00 20                	add    BYTE PTR [eax],ah
#  229:	00 00                	add    BYTE PTR [eax],al
#  22b:	00 1f                	add    BYTE PTR [edi],bl
# 	...
#  235:	00 00                	add    BYTE PTR [eax],al
#  237:	00 22                	add    BYTE PTR [edx],ah
#  239:	00 00                	add    BYTE PTR [eax],al
#  23b:	00 1a                	add    BYTE PTR [edx],bl
# 	...
#  245:	00 00                	add    BYTE PTR [eax],al
#  247:	00 12                	add    BYTE PTR [edx],dl
#  249:	00 00                	add    BYTE PTR [eax],al
#  24b:	00 72 00             	add    BYTE PTR [edx+0x0],dh
# 	...
#  256:	00 00                	add    BYTE PTR [eax],al
#  258:	20 00                	and    BYTE PTR [eax],al
#  25a:	00 00                	add    BYTE PTR [eax],al
#  25c:	2e 00 00             	add    BYTE PTR cs:[eax],al
# 	...
#  267:	00 12                	add    BYTE PTR [edx],dl
#  269:	00 00                	add    BYTE PTR [eax],al
#  26b:	00 81 00 00 00 00    	add    BYTE PTR [ecx+0x0],al
#  271:	00 00                	add    BYTE PTR [eax],al
#  273:	00 00                	add    BYTE PTR [eax],al
#  275:	00 00                	add    BYTE PTR [eax],al
#  277:	00 20                	add    BYTE PTR [eax],ah
#  279:	00 00                	add    BYTE PTR [eax],al
#  27b:	00 0b                	add    BYTE PTR [ebx],cl
#  27d:	00 00                	add    BYTE PTR [eax],al
#  27f:	00 04 20             	add    BYTE PTR [eax+eiz*1],al
#  282:	00 00                	add    BYTE PTR [eax],al
#  284:	04 00                	add    al,0x0
#  286:	00 00                	add    BYTE PTR [eax],al
#  288:	11 00                	adc    DWORD PTR [eax],eax
#  28a:	10 00                	adc    BYTE PTR [eax],al
#
# Disassembly of section .dynstr:
#
# 0000028c <.dynstr>:
#  28c:	00 6c 69 62          	add    BYTE PTR [ecx+ebp*2+0x62],ch
#  290:	63 2e                	arpl   WORD PTR [esi],bp
#  292:	73 6f                	jae    303 <_init-0xcfd>
#  294:	2e 36 00 5f 49       	cs add BYTE PTR ss:[edi+0x49],bl
#  299:	4f                   	dec    edi
#  29a:	5f                   	pop    edi
#  29b:	73 74                	jae    311 <_init-0xcef>
#  29d:	64 69 6e 5f 75 73 65 	imul   ebp,DWORD PTR fs:[esi+0x5f],0x64657375
#  2a4:	64
#  2a5:	00 70 75             	add    BYTE PTR [eax+0x75],dh
#  2a8:	74 73                	je     31d <_init-0xce3>
#  2aa:	00 5f 5f             	add    BYTE PTR [edi+0x5f],bl
#  2ad:	63 78 61             	arpl   WORD PTR [eax+0x61],di
#  2b0:	5f                   	pop    edi
#  2b1:	66 69 6e 61 6c 69    	imul   bp,WORD PTR [esi+0x61],0x696c
#  2b7:	7a 65                	jp     31e <_init-0xce2>
#  2b9:	00 5f 5f             	add    BYTE PTR [edi+0x5f],bl
#  2bc:	6c                   	ins    BYTE PTR es:[edi],dx
#  2bd:	69 62 63 5f 73 74 61 	imul   esp,DWORD PTR [edx+0x63],0x6174735f
#  2c4:	72 74                	jb     33a <_init-0xcc6>
#  2c6:	5f                   	pop    edi
#  2c7:	6d                   	ins    DWORD PTR es:[edi],dx
#  2c8:	61                   	popa
#  2c9:	69 6e 00 47 4c 49 42 	imul   ebp,DWORD PTR [esi+0x0],0x42494c47
#  2d0:	43                   	inc    ebx
#  2d1:	5f                   	pop    edi
#  2d2:	32 2e                	xor    ch,BYTE PTR [esi]
#  2d4:	30 00                	xor    BYTE PTR [eax],al
#  2d6:	47                   	inc    edi
#  2d7:	4c                   	dec    esp
#  2d8:	49                   	dec    ecx
#  2d9:	42                   	inc    edx
#  2da:	43                   	inc    ebx
#  2db:	5f                   	pop    edi
#  2dc:	32 2e                	xor    ch,BYTE PTR [esi]
#  2de:	31 2e                	xor    DWORD PTR [esi],ebp
#  2e0:	33 00                	xor    eax,DWORD PTR [eax]
#  2e2:	5f                   	pop    edi
#  2e3:	49                   	dec    ecx
#  2e4:	54                   	push   esp
#  2e5:	4d                   	dec    ebp
#  2e6:	5f                   	pop    edi
#  2e7:	64 65 72 65          	fs gs jb 350 <_init-0xcb0>
#  2eb:	67 69 73 74 65 72 54 	imul   esi,DWORD PTR [bp+di+0x74],0x4d547265
#  2f2:	4d
#  2f3:	43                   	inc    ebx
#  2f4:	6c                   	ins    BYTE PTR es:[edi],dx
#  2f5:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  2f6:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  2f7:	65 54                	gs push esp
#  2f9:	61                   	popa
#  2fa:	62 6c 65 00          	bound  ebp,QWORD PTR [ebp+eiz*2+0x0]
#  2fe:	5f                   	pop    edi
#  2ff:	5f                   	pop    edi
#  300:	67 6d                	ins    DWORD PTR es:[di],dx
#  302:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  303:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  304:	5f                   	pop    edi
#  305:	73 74                	jae    37b <_init-0xc85>
#  307:	61                   	popa
#  308:	72 74                	jb     37e <_init-0xc82>
#  30a:	5f                   	pop    edi
#  30b:	5f                   	pop    edi
#  30c:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  30f:	54                   	push   esp
#  310:	4d                   	dec    ebp
#  311:	5f                   	pop    edi
#  312:	72 65                	jb     379 <_init-0xc87>
#  314:	67 69 73 74 65 72 54 	imul   esi,DWORD PTR [bp+di+0x74],0x4d547265
#  31b:	4d
#  31c:	43                   	inc    ebx
#  31d:	6c                   	ins    BYTE PTR es:[edi],dx
#  31e:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  31f:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  320:	65 54                	gs push esp
#  322:	61                   	popa
#  323:	62 6c 65 00          	bound  ebp,QWORD PTR [ebp+eiz*2+0x0]
#
# Disassembly of section .gnu.version:
#
# 00000328 <.gnu.version>:
#  328:	00 00                	add    BYTE PTR [eax],al
#  32a:	00 00                	add    BYTE PTR [eax],al
#  32c:	02 00                	add    al,BYTE PTR [eax]
#  32e:	03 00                	add    eax,DWORD PTR [eax]
#  330:	00 00                	add    BYTE PTR [eax],al
#  332:	03 00                	add    eax,DWORD PTR [eax]
#  334:	00 00                	add    BYTE PTR [eax],al
#  336:	01 00                	add    DWORD PTR [eax],eax
#
# Disassembly of section .gnu.version_r:
#
# 00000338 <.gnu.version_r>:
#  338:	01 00                	add    DWORD PTR [eax],eax
#  33a:	02 00                	add    al,BYTE PTR [eax]
#  33c:	01 00                	add    DWORD PTR [eax],eax
#  33e:	00 00                	add    BYTE PTR [eax],al
#  340:	10 00                	adc    BYTE PTR [eax],al
#  342:	00 00                	add    BYTE PTR [eax],al
#  344:	00 00                	add    BYTE PTR [eax],al
#  346:	00 00                	add    BYTE PTR [eax],al
#  348:	10 69 69             	adc    BYTE PTR [ecx+0x69],ch
#  34b:	0d 00 00 03 00       	or     eax,0x30000
#  350:	40                   	inc    eax
#  351:	00 00                	add    BYTE PTR [eax],al
#  353:	00 10                	add    BYTE PTR [eax],dl
#  355:	00 00                	add    BYTE PTR [eax],al
#  357:	00 73 1f             	add    BYTE PTR [ebx+0x1f],dh
#  35a:	69 09 00 00 02 00    	imul   ecx,DWORD PTR [ecx],0x20000
#  360:	4a                   	dec    edx
#  361:	00 00                	add    BYTE PTR [eax],al
#  363:	00 00                	add    BYTE PTR [eax],al
#  365:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .rel.dyn:
#
# 00000368 <.rel.dyn>:
#  368:	f4                   	hlt
#  369:	3e 00 00             	add    BYTE PTR ds:[eax],al
#  36c:	08 00                	or     BYTE PTR [eax],al
#  36e:	00 00                	add    BYTE PTR [eax],al
#  370:	f8                   	clc
#  371:	3e 00 00             	add    BYTE PTR ds:[eax],al
#  374:	08 00                	or     BYTE PTR [eax],al
#  376:	00 00                	add    BYTE PTR [eax],al
#  378:	f8                   	clc
#  379:	3f                   	aas
#  37a:	00 00                	add    BYTE PTR [eax],al
#  37c:	08 00                	or     BYTE PTR [eax],al
#  37e:	00 00                	add    BYTE PTR [eax],al
#  380:	18 40 00             	sbb    BYTE PTR [eax+0x0],al
#  383:	00 08                	add    BYTE PTR [eax],cl
#  385:	00 00                	add    BYTE PTR [eax],al
#  387:	00 ec                	add    ah,ch
#  389:	3f                   	aas
#  38a:	00 00                	add    BYTE PTR [eax],al
#  38c:	06                   	push   es
#  38d:	01 00                	add    DWORD PTR [eax],eax
#  38f:	00 f0                	add    al,dh
#  391:	3f                   	aas
#  392:	00 00                	add    BYTE PTR [eax],al
#  394:	06                   	push   es
#  395:	02 00                	add    al,BYTE PTR [eax]
#  397:	00 f4                	add    ah,dh
#  399:	3f                   	aas
#  39a:	00 00                	add    BYTE PTR [eax],al
#  39c:	06                   	push   es
#  39d:	04 00                	add    al,0x0
#  39f:	00 fc                	add    ah,bh
#  3a1:	3f                   	aas
#  3a2:	00 00                	add    BYTE PTR [eax],al
#  3a4:	06                   	push   es
#  3a5:	06                   	push   es
# 	...
#
# Disassembly of section .rel.plt:
#
# 000003a8 <.rel.plt>:
#  3a8:	0c 40                	or     al,0x40
#  3aa:	00 00                	add    BYTE PTR [eax],al
#  3ac:	07                   	pop    es
#  3ad:	03 00                	add    eax,DWORD PTR [eax]
#  3af:	00 10                	add    BYTE PTR [eax],dl
#  3b1:	40                   	inc    eax
#  3b2:	00 00                	add    BYTE PTR [eax],al
#  3b4:	07                   	pop    es
#  3b5:	05                   	.byte 0x5
# 	...
#
# Disassembly of section .init:
#
# 00001000 <_init>:
#     1000:	53                   	push   ebx
#     1001:	83 ec 08             	sub    esp,0x8
#     1004:	e8 97 00 00 00       	call   10a0 <__x86.get_pc_thunk.bx>
#     1009:	81 c3 f7 2f 00 00    	add    ebx,0x2ff7
#     100f:	8b 83 f4 ff ff ff    	mov    eax,DWORD PTR [ebx-0xc]
#     1015:	85 c0                	test   eax,eax
#     1017:	74 02                	je     101b <_init+0x1b>
#     1019:	ff d0                	call   eax
#     101b:	83 c4 08             	add    esp,0x8
#     101e:	5b                   	pop    ebx
#     101f:	c3                   	ret
#
# Disassembly of section .plt:
#
# 00001020 <.plt>:
#     1020:	ff b3 04 00 00 00    	push   DWORD PTR [ebx+0x4]
#     1026:	ff a3 08 00 00 00    	jmp    DWORD PTR [ebx+0x8]
#     102c:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# 00001030 <puts@plt>:
#     1030:	ff a3 0c 00 00 00    	jmp    DWORD PTR [ebx+0xc]
#     1036:	68 00 00 00 00       	push   0x0
#     103b:	e9 e0 ff ff ff       	jmp    1020 <.plt>
#
# 00001040 <__libc_start_main@plt>:
#     1040:	ff a3 10 00 00 00    	jmp    DWORD PTR [ebx+0x10]
#     1046:	68 08 00 00 00       	push   0x8
#     104b:	e9 d0 ff ff ff       	jmp    1020 <.plt>
#
# Disassembly of section .plt.got:
#
# 00001050 <__cxa_finalize@plt>:
#     1050:	ff a3 f0 ff ff ff    	jmp    DWORD PTR [ebx-0x10]
#     1056:	66 90                	xchg   ax,ax
#
# Disassembly of section .text:
#
# 00001060 <_start>:
#     1060:	31 ed                	xor    ebp,ebp
#     1062:	5e                   	pop    esi
#     1063:	89 e1                	mov    ecx,esp
#     1065:	83 e4 f0             	and    esp,0xfffffff0
#     1068:	50                   	push   eax
#     1069:	54                   	push   esp
#     106a:	52                   	push   edx
#     106b:	e8 22 00 00 00       	call   1092 <_start+0x32>
#     1070:	81 c3 90 2f 00 00    	add    ebx,0x2f90
#     1076:	8d 83 40 d2 ff ff    	lea    eax,[ebx-0x2dc0]
#     107c:	50                   	push   eax
#     107d:	8d 83 e0 d1 ff ff    	lea    eax,[ebx-0x2e20]
#     1083:	50                   	push   eax
#     1084:	51                   	push   ecx
#     1085:	56                   	push   esi
#     1086:	ff b3 f8 ff ff ff    	push   DWORD PTR [ebx-0x8]
#     108c:	e8 af ff ff ff       	call   1040 <__libc_start_main@plt>
#     1091:	f4                   	hlt
#     1092:	8b 1c 24             	mov    ebx,DWORD PTR [esp]
#     1095:	c3                   	ret
#     1096:	66 90                	xchg   ax,ax
#     1098:	66 90                	xchg   ax,ax
#     109a:	66 90                	xchg   ax,ax
#     109c:	66 90                	xchg   ax,ax
#     109e:	66 90                	xchg   ax,ax
#
# 000010a0 <__x86.get_pc_thunk.bx>:
#     10a0:	8b 1c 24             	mov    ebx,DWORD PTR [esp]
#     10a3:	c3                   	ret
#     10a4:	66 90                	xchg   ax,ax
#     10a6:	66 90                	xchg   ax,ax
#     10a8:	66 90                	xchg   ax,ax
#     10aa:	66 90                	xchg   ax,ax
#     10ac:	66 90                	xchg   ax,ax
#     10ae:	66 90                	xchg   ax,ax
#
# 000010b0 <deregister_tm_clones>:
#     10b0:	e8 e0 00 00 00       	call   1195 <__x86.get_pc_thunk.dx>
#     10b5:	81 c2 4b 2f 00 00    	add    edx,0x2f4b
#     10bb:	8d 8a 1c 00 00 00    	lea    ecx,[edx+0x1c]
#     10c1:	8d 82 1c 00 00 00    	lea    eax,[edx+0x1c]
#     10c7:	39 c8                	cmp    eax,ecx
#     10c9:	74 1d                	je     10e8 <deregister_tm_clones+0x38>
#     10cb:	8b 82 ec ff ff ff    	mov    eax,DWORD PTR [edx-0x14]
#     10d1:	85 c0                	test   eax,eax
#     10d3:	74 13                	je     10e8 <deregister_tm_clones+0x38>
#     10d5:	55                   	push   ebp
#     10d6:	89 e5                	mov    ebp,esp
#     10d8:	83 ec 14             	sub    esp,0x14
#     10db:	51                   	push   ecx
#     10dc:	ff d0                	call   eax
#     10de:	83 c4 10             	add    esp,0x10
#     10e1:	c9                   	leave
#     10e2:	c3                   	ret
#     10e3:	8d 74 26 00          	lea    esi,[esi+eiz*1+0x0]
#     10e7:	90                   	nop
#     10e8:	c3                   	ret
#     10e9:	8d b4 26 00 00 00 00 	lea    esi,[esi+eiz*1+0x0]
#
# 000010f0 <register_tm_clones>:
#     10f0:	e8 a0 00 00 00       	call   1195 <__x86.get_pc_thunk.dx>
#     10f5:	81 c2 0b 2f 00 00    	add    edx,0x2f0b
#     10fb:	55                   	push   ebp
#     10fc:	89 e5                	mov    ebp,esp
#     10fe:	53                   	push   ebx
#     10ff:	8d 8a 1c 00 00 00    	lea    ecx,[edx+0x1c]
#     1105:	8d 82 1c 00 00 00    	lea    eax,[edx+0x1c]
#     110b:	83 ec 04             	sub    esp,0x4
#     110e:	29 c8                	sub    eax,ecx
#     1110:	89 c3                	mov    ebx,eax
#     1112:	c1 e8 1f             	shr    eax,0x1f
#     1115:	c1 fb 02             	sar    ebx,0x2
#     1118:	01 d8                	add    eax,ebx
#     111a:	d1 f8                	sar    eax,1
#     111c:	74 14                	je     1132 <register_tm_clones+0x42>
#     111e:	8b 92 fc ff ff ff    	mov    edx,DWORD PTR [edx-0x4]
#     1124:	85 d2                	test   edx,edx
#     1126:	74 0a                	je     1132 <register_tm_clones+0x42>
#     1128:	83 ec 08             	sub    esp,0x8
#     112b:	50                   	push   eax
#     112c:	51                   	push   ecx
#     112d:	ff d2                	call   edx
#     112f:	83 c4 10             	add    esp,0x10
#     1132:	8b 5d fc             	mov    ebx,DWORD PTR [ebp-0x4]
#     1135:	c9                   	leave
#     1136:	c3                   	ret
#     1137:	8d b4 26 00 00 00 00 	lea    esi,[esi+eiz*1+0x0]
#     113e:	66 90                	xchg   ax,ax
#
# 00001140 <__do_global_dtors_aux>:
#     1140:	55                   	push   ebp
#     1141:	89 e5                	mov    ebp,esp
#     1143:	53                   	push   ebx
#     1144:	e8 57 ff ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     1149:	81 c3 b7 2e 00 00    	add    ebx,0x2eb7
#     114f:	83 ec 04             	sub    esp,0x4
#     1152:	80 bb 1c 00 00 00 00 	cmp    BYTE PTR [ebx+0x1c],0x0
#     1159:	75 27                	jne    1182 <__do_global_dtors_aux+0x42>
#     115b:	8b 83 f0 ff ff ff    	mov    eax,DWORD PTR [ebx-0x10]
#     1161:	85 c0                	test   eax,eax
#     1163:	74 11                	je     1176 <__do_global_dtors_aux+0x36>
#     1165:	83 ec 0c             	sub    esp,0xc
#     1168:	ff b3 18 00 00 00    	push   DWORD PTR [ebx+0x18]
#     116e:	e8 dd fe ff ff       	call   1050 <__cxa_finalize@plt>
#     1173:	83 c4 10             	add    esp,0x10
#     1176:	e8 35 ff ff ff       	call   10b0 <deregister_tm_clones>
#     117b:	c6 83 1c 00 00 00 01 	mov    BYTE PTR [ebx+0x1c],0x1
#     1182:	8b 5d fc             	mov    ebx,DWORD PTR [ebp-0x4]
#     1185:	c9                   	leave
#     1186:	c3                   	ret
#     1187:	8d b4 26 00 00 00 00 	lea    esi,[esi+eiz*1+0x0]
#     118e:	66 90                	xchg   ax,ax
#
# 00001190 <frame_dummy>:
#     1190:	e9 5b ff ff ff       	jmp    10f0 <register_tm_clones>
#
# 00001195 <__x86.get_pc_thunk.dx>:
#     1195:	8b 14 24             	mov    edx,DWORD PTR [esp]
#     1198:	c3                   	ret
#
# 00001199 <main>:
#     1199:	8d 4c 24 04          	lea    ecx,[esp+0x4]
#     119d:	83 e4 f0             	and    esp,0xfffffff0
#     11a0:	ff 71 fc             	push   DWORD PTR [ecx-0x4]
#     11a3:	55                   	push   ebp
#     11a4:	89 e5                	mov    ebp,esp
#     11a6:	53                   	push   ebx
#     11a7:	51                   	push   ecx
#     11a8:	e8 28 00 00 00       	call   11d5 <__x86.get_pc_thunk.ax>
#     11ad:	05 53 2e 00 00       	add    eax,0x2e53
#     11b2:	83 ec 0c             	sub    esp,0xc
#     11b5:	8d 90 08 e0 ff ff    	lea    edx,[eax-0x1ff8]
#     11bb:	52                   	push   edx
#     11bc:	89 c3                	mov    ebx,eax
#     11be:	e8 6d fe ff ff       	call   1030 <puts@plt>
#     11c3:	83 c4 10             	add    esp,0x10
#     11c6:	b8 00 00 00 00       	mov    eax,0x0
#     11cb:	8d 65 f8             	lea    esp,[ebp-0x8]
#     11ce:	59                   	pop    ecx
#     11cf:	5b                   	pop    ebx
#     11d0:	5d                   	pop    ebp
#     11d1:	8d 61 fc             	lea    esp,[ecx-0x4]
#     11d4:	c3                   	ret
#
# 000011d5 <__x86.get_pc_thunk.ax>:
#     11d5:	8b 04 24             	mov    eax,DWORD PTR [esp]
#     11d8:	c3                   	ret
#     11d9:	66 90                	xchg   ax,ax
#     11db:	66 90                	xchg   ax,ax
#     11dd:	66 90                	xchg   ax,ax
#     11df:	90                   	nop
#
# 000011e0 <__libc_csu_init>:
#     11e0:	55                   	push   ebp
#     11e1:	e8 5b 00 00 00       	call   1241 <__x86.get_pc_thunk.bp>
#     11e6:	81 c5 1a 2e 00 00    	add    ebp,0x2e1a
#     11ec:	57                   	push   edi
#     11ed:	56                   	push   esi
#     11ee:	53                   	push   ebx
#     11ef:	83 ec 0c             	sub    esp,0xc
#     11f2:	89 eb                	mov    ebx,ebp
#     11f4:	8b 7c 24 28          	mov    edi,DWORD PTR [esp+0x28]
#     11f8:	e8 03 fe ff ff       	call   1000 <_init>
#     11fd:	8d 9d f8 fe ff ff    	lea    ebx,[ebp-0x108]
#     1203:	8d 85 f4 fe ff ff    	lea    eax,[ebp-0x10c]
#     1209:	29 c3                	sub    ebx,eax
#     120b:	c1 fb 02             	sar    ebx,0x2
#     120e:	74 25                	je     1235 <__libc_csu_init+0x55>
#     1210:	31 f6                	xor    esi,esi
#     1212:	8d b6 00 00 00 00    	lea    esi,[esi+0x0]
#     1218:	83 ec 04             	sub    esp,0x4
#     121b:	57                   	push   edi
#     121c:	ff 74 24 2c          	push   DWORD PTR [esp+0x2c]
#     1220:	ff 74 24 2c          	push   DWORD PTR [esp+0x2c]
#     1224:	ff 94 b5 f4 fe ff ff 	call   DWORD PTR [ebp+esi*4-0x10c]
#     122b:	83 c6 01             	add    esi,0x1
#     122e:	83 c4 10             	add    esp,0x10
#     1231:	39 f3                	cmp    ebx,esi
#     1233:	75 e3                	jne    1218 <__libc_csu_init+0x38>
#     1235:	83 c4 0c             	add    esp,0xc
#     1238:	5b                   	pop    ebx
#     1239:	5e                   	pop    esi
#     123a:	5f                   	pop    edi
#     123b:	5d                   	pop    ebp
#     123c:	c3                   	ret
#     123d:	8d 76 00             	lea    esi,[esi+0x0]
#
# 00001240 <__libc_csu_fini>:
#     1240:	c3                   	ret
#
# 00001241 <__x86.get_pc_thunk.bp>:
#     1241:	8b 2c 24             	mov    ebp,DWORD PTR [esp]
#     1244:	c3                   	ret
#
# Disassembly of section .fini:
#
# 00001248 <_fini>:
#     1248:	53                   	push   ebx
#     1249:	83 ec 08             	sub    esp,0x8
#     124c:	e8 4f fe ff ff       	call   10a0 <__x86.get_pc_thunk.bx>
#     1251:	81 c3 af 2d 00 00    	add    ebx,0x2daf
#     1257:	83 c4 08             	add    esp,0x8
#     125a:	5b                   	pop    ebx
#     125b:	c3                   	ret
#
# Disassembly of section .rodata:
#
# 00002000 <_fp_hw>:
#     2000:	03 00                	add    eax,DWORD PTR [eax]
# 	...
#
# 00002004 <_IO_stdin_used>:
#     2004:	01 00                	add    DWORD PTR [eax],eax
#     2006:	02 00                	add    al,BYTE PTR [eax]
#     2008:	48                   	dec    eax
#     2009:	65 6c                	gs ins BYTE PTR es:[edi],dx
#     200b:	6c                   	ins    BYTE PTR es:[edi],dx
#     200c:	6f                   	outs   dx,DWORD PTR ds:[esi]
#     200d:	20 57 6f             	and    BYTE PTR [edi+0x6f],dl
#     2010:	72 6c                	jb     207e <__GNU_EH_FRAME_HDR+0x66>
#     2012:	64 21 00             	and    DWORD PTR fs:[eax],eax
#
# Disassembly of section .eh_frame_hdr:
#
# 00002018 <__GNU_EH_FRAME_HDR>:
#     2018:	01 1b                	add    DWORD PTR [ebx],ebx
#     201a:	03 3b                	add    edi,DWORD PTR [ebx]
#     201c:	48                   	dec    eax
#     201d:	00 00                	add    BYTE PTR [eax],al
#     201f:	00 08                	add    BYTE PTR [eax],cl
#     2021:	00 00                	add    BYTE PTR [eax],al
#     2023:	00 08                	add    BYTE PTR [eax],cl
#     2025:	f0 ff                	lock (bad)
#     2027:	ff 90 00 00 00 38    	call   DWORD PTR [eax+0x38000000]
#     202d:	f0 ff                	lock (bad)
#     202f:	ff b4 00 00 00 48 f0 	push   DWORD PTR [eax+eax*1-0xfb80000]
#     2036:	ff                   	(bad)
#     2037:	ff 64 00 00          	jmp    DWORD PTR [eax+eax*1+0x0]
#     203b:	00 81 f1 ff ff c8    	add    BYTE PTR [ecx-0x3700000f],al
#     2041:	00 00                	add    BYTE PTR [eax],al
#     2043:	00 bd f1 ff ff fc    	add    BYTE PTR [ebp-0x300000f],bh
#     2049:	00 00                	add    BYTE PTR [eax],al
#     204b:	00 c8                	add    al,cl
#     204d:	f1                   	icebp
#     204e:	ff                   	(bad)
#     204f:	ff 10                	call   DWORD PTR [eax]
#     2051:	01 00                	add    DWORD PTR [eax],eax
#     2053:	00 28                	add    BYTE PTR [eax],ch
#     2055:	f2 ff                	repnz (bad)
#     2057:	ff 5c 01 00          	call   FWORD PTR [ecx+eax*1+0x0]
#     205b:	00 29                	add    BYTE PTR [ecx],ch
#     205d:	f2 ff                	repnz (bad)
#     205f:	ff 70 01             	push   DWORD PTR [eax+0x1]
# 	...
#
# Disassembly of section .eh_frame:
#
# 00002064 <__FRAME_END__-0x138>:
#     2064:	14 00                	adc    al,0x0
#     2066:	00 00                	add    BYTE PTR [eax],al
#     2068:	00 00                	add    BYTE PTR [eax],al
#     206a:	00 00                	add    BYTE PTR [eax],al
#     206c:	01 7a 52             	add    DWORD PTR [edx+0x52],edi
#     206f:	00 01                	add    BYTE PTR [ecx],al
#     2071:	7c 08                	jl     207b <__GNU_EH_FRAME_HDR+0x63>
#     2073:	01 1b                	add    DWORD PTR [ebx],ebx
#     2075:	0c 04                	or     al,0x4
#     2077:	04 88                	add    al,0x88
#     2079:	01 07                	add    DWORD PTR [edi],eax
#     207b:	08 10                	or     BYTE PTR [eax],dl
#     207d:	00 00                	add    BYTE PTR [eax],al
#     207f:	00 1c 00             	add    BYTE PTR [eax+eax*1],bl
#     2082:	00 00                	add    BYTE PTR [eax],al
#     2084:	dc ef                	fsub   st(7),st
#     2086:	ff                   	(bad)
#     2087:	ff 36                	push   DWORD PTR [esi]
#     2089:	00 00                	add    BYTE PTR [eax],al
#     208b:	00 00                	add    BYTE PTR [eax],al
#     208d:	00 00                	add    BYTE PTR [eax],al
#     208f:	00 14 00             	add    BYTE PTR [eax+eax*1],dl
#     2092:	00 00                	add    BYTE PTR [eax],al
#     2094:	00 00                	add    BYTE PTR [eax],al
#     2096:	00 00                	add    BYTE PTR [eax],al
#     2098:	01 7a 52             	add    DWORD PTR [edx+0x52],edi
#     209b:	00 01                	add    BYTE PTR [ecx],al
#     209d:	7c 08                	jl     20a7 <__GNU_EH_FRAME_HDR+0x8f>
#     209f:	01 1b                	add    DWORD PTR [ebx],ebx
#     20a1:	0c 04                	or     al,0x4
#     20a3:	04 88                	add    al,0x88
#     20a5:	01 00                	add    DWORD PTR [eax],eax
#     20a7:	00 20                	add    BYTE PTR [eax],ah
#     20a9:	00 00                	add    BYTE PTR [eax],al
#     20ab:	00 1c 00             	add    BYTE PTR [eax+eax*1],bl
#     20ae:	00 00                	add    BYTE PTR [eax],al
#     20b0:	70 ef                	jo     20a1 <__GNU_EH_FRAME_HDR+0x89>
#     20b2:	ff                   	(bad)
#     20b3:	ff 30                	push   DWORD PTR [eax]
#     20b5:	00 00                	add    BYTE PTR [eax],al
#     20b7:	00 00                	add    BYTE PTR [eax],al
#     20b9:	0e                   	push   cs
#     20ba:	08 46 0e             	or     BYTE PTR [esi+0xe],al
#     20bd:	0c 4a                	or     al,0x4a
#     20bf:	0f 0b                	ud2
#     20c1:	74 04                	je     20c7 <__GNU_EH_FRAME_HDR+0xaf>
#     20c3:	78 00                	js     20c5 <__GNU_EH_FRAME_HDR+0xad>
#     20c5:	3f                   	aas
#     20c6:	1a 3b                	sbb    bh,BYTE PTR [ebx]
#     20c8:	2a 32                	sub    dh,BYTE PTR [edx]
#     20ca:	24 22                	and    al,0x22
#     20cc:	10 00                	adc    BYTE PTR [eax],al
#     20ce:	00 00                	add    BYTE PTR [eax],al
#     20d0:	40                   	inc    eax
#     20d1:	00 00                	add    BYTE PTR [eax],al
#     20d3:	00 7c ef ff          	add    BYTE PTR [edi+ebp*8-0x1],bh
#     20d7:	ff 08                	dec    DWORD PTR [eax]
#     20d9:	00 00                	add    BYTE PTR [eax],al
#     20db:	00 00                	add    BYTE PTR [eax],al
#     20dd:	00 00                	add    BYTE PTR [eax],al
#     20df:	00 30                	add    BYTE PTR [eax],dh
#     20e1:	00 00                	add    BYTE PTR [eax],al
#     20e3:	00 54 00 00          	add    BYTE PTR [eax+eax*1+0x0],dl
#     20e7:	00 b1 f0 ff ff 3c    	add    BYTE PTR [ecx+0x3cfffff0],dh
#     20ed:	00 00                	add    BYTE PTR [eax],al
#     20ef:	00 00                	add    BYTE PTR [eax],al
#     20f1:	44                   	inc    esp
#     20f2:	0c 01                	or     al,0x1
#     20f4:	00 47 10             	add    BYTE PTR [edi+0x10],al
#     20f7:	05 02 75 00 44       	add    eax,0x44007502
#     20fc:	0f 03 75 78          	lsl    esi,WORD PTR [ebp+0x78]
#     2100:	06                   	push   es
#     2101:	10 03                	adc    BYTE PTR [ebx],al
#     2103:	02 75 7c             	add    dh,BYTE PTR [ebp+0x7c]
#     2106:	67 c1 0c 01          	ror    DWORD PTR [si],0x1
#     210a:	00 41 c3             	add    BYTE PTR [ecx-0x3d],al
#     210d:	41                   	inc    ecx
#     210e:	c5 43 0c             	lds    eax,FWORD PTR [ebx+0xc]
#     2111:	04 04                	add    al,0x4
#     2113:	00 10                	add    BYTE PTR [eax],dl
#     2115:	00 00                	add    BYTE PTR [eax],al
#     2117:	00 88 00 00 00 b9    	add    BYTE PTR [eax-0x47000000],cl
#     211d:	f0 ff                	lock (bad)
#     211f:	ff 04 00             	inc    DWORD PTR [eax+eax*1]
#     2122:	00 00                	add    BYTE PTR [eax],al
#     2124:	00 00                	add    BYTE PTR [eax],al
#     2126:	00 00                	add    BYTE PTR [eax],al
#     2128:	48                   	dec    eax
#     2129:	00 00                	add    BYTE PTR [eax],al
#     212b:	00 9c 00 00 00 b0 f0 	add    BYTE PTR [eax+eax*1-0xf500000],bl
#     2132:	ff                   	(bad)
#     2133:	ff 5d 00             	call   FWORD PTR [ebp+0x0]
#     2136:	00 00                	add    BYTE PTR [eax],al
#     2138:	00 41 0e             	add    BYTE PTR [ecx+0xe],al
#     213b:	08 85 02 4c 0e 0c    	or     BYTE PTR [ebp+0xc0e4c02],al
#     2141:	87 03                	xchg   DWORD PTR [ebx],eax
#     2143:	41                   	inc    ecx
#     2144:	0e                   	push   cs
#     2145:	10 86 04 41 0e 14    	adc    BYTE PTR [esi+0x140e4104],al
#     214b:	83 05 43 0e 20 69 0e 	add    DWORD PTR ds:0x69200e43,0xe
#     2152:	24 41                	and    al,0x41
#     2154:	0e                   	push   cs
#     2155:	28 44 0e 2c          	sub    BYTE PTR [esi+ecx*1+0x2c],al
#     2159:	44                   	inc    esp
#     215a:	0e                   	push   cs
#     215b:	30 4d 0e             	xor    BYTE PTR [ebp+0xe],cl
#     215e:	20 47 0e             	and    BYTE PTR [edi+0xe],al
#     2161:	14 41                	adc    al,0x41
#     2163:	c3                   	ret
#     2164:	0e                   	push   cs
#     2165:	10 41 c6             	adc    BYTE PTR [ecx-0x3a],al
#     2168:	0e                   	push   cs
#     2169:	0c 41                	or     al,0x41
#     216b:	c7                   	(bad)
#     216c:	0e                   	push   cs
#     216d:	08 41 c5             	or     BYTE PTR [ecx-0x3b],al
#     2170:	0e                   	push   cs
#     2171:	04 00                	add    al,0x0
#     2173:	00 10                	add    BYTE PTR [eax],dl
#     2175:	00 00                	add    BYTE PTR [eax],al
#     2177:	00 e8                	add    al,ch
#     2179:	00 00                	add    BYTE PTR [eax],al
#     217b:	00 c4                	add    ah,al
#     217d:	f0 ff                	lock (bad)
#     217f:	ff 01                	inc    DWORD PTR [ecx]
#     2181:	00 00                	add    BYTE PTR [eax],al
#     2183:	00 00                	add    BYTE PTR [eax],al
#     2185:	00 00                	add    BYTE PTR [eax],al
#     2187:	00 10                	add    BYTE PTR [eax],dl
#     2189:	00 00                	add    BYTE PTR [eax],al
#     218b:	00 fc                	add    ah,bh
#     218d:	00 00                	add    BYTE PTR [eax],al
#     218f:	00 b1 f0 ff ff 04    	add    BYTE PTR [ecx+0x4fffff0],dh
#     2195:	00 00                	add    BYTE PTR [eax],al
#     2197:	00 00                	add    BYTE PTR [eax],al
#     2199:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# 0000219c <__FRAME_END__>:
#     219c:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .init_array:
#
# 00003ef4 <__frame_dummy_init_array_entry>:
#     3ef4:	90                   	nop
#     3ef5:	11 00                	adc    DWORD PTR [eax],eax
# 	...
#
# Disassembly of section .fini_array:
#
# 00003ef8 <__do_global_dtors_aux_fini_array_entry>:
#     3ef8:	40                   	inc    eax
#     3ef9:	11 00                	adc    DWORD PTR [eax],eax
# 	...
#
# Disassembly of section .dynamic:
#
# 00003efc <_DYNAMIC>:
#     3efc:	01 00                	add    DWORD PTR [eax],eax
#     3efe:	00 00                	add    BYTE PTR [eax],al
#     3f00:	01 00                	add    DWORD PTR [eax],eax
#     3f02:	00 00                	add    BYTE PTR [eax],al
#     3f04:	0c 00                	or     al,0x0
#     3f06:	00 00                	add    BYTE PTR [eax],al
#     3f08:	00 10                	add    BYTE PTR [eax],dl
#     3f0a:	00 00                	add    BYTE PTR [eax],al
#     3f0c:	0d 00 00 00 48       	or     eax,0x48000000
#     3f11:	12 00                	adc    al,BYTE PTR [eax]
#     3f13:	00 19                	add    BYTE PTR [ecx],bl
#     3f15:	00 00                	add    BYTE PTR [eax],al
#     3f17:	00 f4                	add    ah,dh
#     3f19:	3e 00 00             	add    BYTE PTR ds:[eax],al
#     3f1c:	1b 00                	sbb    eax,DWORD PTR [eax]
#     3f1e:	00 00                	add    BYTE PTR [eax],al
#     3f20:	04 00                	add    al,0x0
#     3f22:	00 00                	add    BYTE PTR [eax],al
#     3f24:	1a 00                	sbb    al,BYTE PTR [eax]
#     3f26:	00 00                	add    BYTE PTR [eax],al
#     3f28:	f8                   	clc
#     3f29:	3e 00 00             	add    BYTE PTR ds:[eax],al
#     3f2c:	1c 00                	sbb    al,0x0
#     3f2e:	00 00                	add    BYTE PTR [eax],al
#     3f30:	04 00                	add    al,0x0
#     3f32:	00 00                	add    BYTE PTR [eax],al
#     3f34:	f5                   	cmc
#     3f35:	fe                   	(bad)
#     3f36:	ff 6f ec             	jmp    FWORD PTR [edi-0x14]
#     3f39:	01 00                	add    DWORD PTR [eax],eax
#     3f3b:	00 05 00 00 00 8c    	add    BYTE PTR ds:0x8c000000,al
#     3f41:	02 00                	add    al,BYTE PTR [eax]
#     3f43:	00 06                	add    BYTE PTR [esi],al
#     3f45:	00 00                	add    BYTE PTR [eax],al
#     3f47:	00 0c 02             	add    BYTE PTR [edx+eax*1],cl
#     3f4a:	00 00                	add    BYTE PTR [eax],al
#     3f4c:	0a 00                	or     al,BYTE PTR [eax]
#     3f4e:	00 00                	add    BYTE PTR [eax],al
#     3f50:	9b                   	fwait
#     3f51:	00 00                	add    BYTE PTR [eax],al
#     3f53:	00 0b                	add    BYTE PTR [ebx],cl
#     3f55:	00 00                	add    BYTE PTR [eax],al
#     3f57:	00 10                	add    BYTE PTR [eax],dl
#     3f59:	00 00                	add    BYTE PTR [eax],al
#     3f5b:	00 15 00 00 00 00    	add    BYTE PTR ds:0x0,dl
#     3f61:	00 00                	add    BYTE PTR [eax],al
#     3f63:	00 03                	add    BYTE PTR [ebx],al
#     3f65:	00 00                	add    BYTE PTR [eax],al
#     3f67:	00 00                	add    BYTE PTR [eax],al
#     3f69:	40                   	inc    eax
#     3f6a:	00 00                	add    BYTE PTR [eax],al
#     3f6c:	02 00                	add    al,BYTE PTR [eax]
#     3f6e:	00 00                	add    BYTE PTR [eax],al
#     3f70:	10 00                	adc    BYTE PTR [eax],al
#     3f72:	00 00                	add    BYTE PTR [eax],al
#     3f74:	14 00                	adc    al,0x0
#     3f76:	00 00                	add    BYTE PTR [eax],al
#     3f78:	11 00                	adc    DWORD PTR [eax],eax
#     3f7a:	00 00                	add    BYTE PTR [eax],al
#     3f7c:	17                   	pop    ss
#     3f7d:	00 00                	add    BYTE PTR [eax],al
#     3f7f:	00 a8 03 00 00 11    	add    BYTE PTR [eax+0x11000003],ch
#     3f85:	00 00                	add    BYTE PTR [eax],al
#     3f87:	00 68 03             	add    BYTE PTR [eax+0x3],ch
#     3f8a:	00 00                	add    BYTE PTR [eax],al
#     3f8c:	12 00                	adc    al,BYTE PTR [eax]
#     3f8e:	00 00                	add    BYTE PTR [eax],al
#     3f90:	40                   	inc    eax
#     3f91:	00 00                	add    BYTE PTR [eax],al
#     3f93:	00 13                	add    BYTE PTR [ebx],dl
#     3f95:	00 00                	add    BYTE PTR [eax],al
#     3f97:	00 08                	add    BYTE PTR [eax],cl
#     3f99:	00 00                	add    BYTE PTR [eax],al
#     3f9b:	00 fb                	add    bl,bh
#     3f9d:	ff                   	(bad)
#     3f9e:	ff 6f 00             	jmp    FWORD PTR [edi+0x0]
#     3fa1:	00 00                	add    BYTE PTR [eax],al
#     3fa3:	08 fe                	or     dh,bh
#     3fa5:	ff                   	(bad)
#     3fa6:	ff 6f 38             	jmp    FWORD PTR [edi+0x38]
#     3fa9:	03 00                	add    eax,DWORD PTR [eax]
#     3fab:	00 ff                	add    bh,bh
#     3fad:	ff                   	(bad)
#     3fae:	ff 6f 01             	jmp    FWORD PTR [edi+0x1]
#     3fb1:	00 00                	add    BYTE PTR [eax],al
#     3fb3:	00 f0                	add    al,dh
#     3fb5:	ff                   	(bad)
#     3fb6:	ff 6f 28             	jmp    FWORD PTR [edi+0x28]
#     3fb9:	03 00                	add    eax,DWORD PTR [eax]
#     3fbb:	00 fa                	add    dl,bh
#     3fbd:	ff                   	(bad)
#     3fbe:	ff 6f 04             	jmp    FWORD PTR [edi+0x4]
# 	...
#
# Disassembly of section .got:
#
# 00003fec <.got>:
# 	...
#     3ff8:	99                   	cdq
#     3ff9:	11 00                	adc    DWORD PTR [eax],eax
#     3ffb:	00 00                	add    BYTE PTR [eax],al
#     3ffd:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .got.plt:
#
# 00004000 <_GLOBAL_OFFSET_TABLE_>:
#     4000:	fc                   	cld
#     4001:	3e 00 00             	add    BYTE PTR ds:[eax],al
# 	...
#     400c:	36 10 00             	adc    BYTE PTR ss:[eax],al
#     400f:	00 46 10             	add    BYTE PTR [esi+0x10],al
# 	...
#
# Disassembly of section .data:
#
# 00004014 <__data_start>:
#     4014:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# 00004018 <__dso_handle>:
#     4018:	18 40 00             	sbb    BYTE PTR [eax+0x0],al
# 	...
#
# Disassembly of section .bss:
#
# 0000401c <completed.7003>:
#     401c:	00 00                	add    BYTE PTR [eax],al
# 	...
#
# Disassembly of section .comment:
#
# 00000000 <.comment>:
#    0:	47                   	inc    edi
#    1:	43                   	inc    ebx
#    2:	43                   	inc    ebx
#    3:	3a 20                	cmp    ah,BYTE PTR [eax]
#    5:	28 44 65 62          	sub    BYTE PTR [ebp+eiz*2+0x62],al
#    9:	69 61 6e 20 39 2e 32 	imul   esp,DWORD PTR [ecx+0x6e],0x322e3920
#   10:	2e 31 2d 32 35 29 20 	xor    DWORD PTR cs:0x20293532,ebp
#   17:	39 2e                	cmp    DWORD PTR [esi],ebp
#   19:	32 2e                	xor    ch,BYTE PTR [esi]
#   1b:	31 20                	xor    DWORD PTR [eax],esp
#   1d:	32 30                	xor    dh,BYTE PTR [eax]
#   1f:	32 30                	xor    dh,BYTE PTR [eax]
#   21:	30 31                	xor    BYTE PTR [ecx],dh
#   23:	32 33                	xor    dh,BYTE PTR [ebx]
# 	...
#
# Disassembly of section .debug_aranges:
#
# 00000000 <.debug_aranges>:
#    0:	1c 00                	sbb    al,0x0
#    2:	00 00                	add    BYTE PTR [eax],al
#    4:	02 00                	add    al,BYTE PTR [eax]
#    6:	00 00                	add    BYTE PTR [eax],al
#    8:	00 00                	add    BYTE PTR [eax],al
#    a:	04 00                	add    al,0x0
#    c:	00 00                	add    BYTE PTR [eax],al
#    e:	00 00                	add    BYTE PTR [eax],al
#   10:	99                   	cdq
#   11:	11 00                	adc    DWORD PTR [eax],eax
#   13:	00 3c 00             	add    BYTE PTR [eax+eax*1],bh
# 	...
#
# Disassembly of section .debug_info:
#
# 00000000 <.debug_info>:
#    0:	07                   	pop    es
#    1:	03 00                	add    eax,DWORD PTR [eax]
#    3:	00 04 00             	add    BYTE PTR [eax+eax*1],al
#    6:	00 00                	add    BYTE PTR [eax],al
#    8:	00 00                	add    BYTE PTR [eax],al
#    a:	04 01                	add    al,0x1
#    c:	db 00                	fild   DWORD PTR [eax]
#    e:	00 00                	add    BYTE PTR [eax],al
#   10:	0c 0c                	or     al,0xc
#   12:	00 00                	add    BYTE PTR [eax],al
#   14:	00 95 01 00 00 99    	add    BYTE PTR [ebp-0x66ffffff],dl
#   1a:	11 00                	adc    DWORD PTR [eax],eax
#   1c:	00 3c 00             	add    BYTE PTR [eax+eax*1],bh
#   1f:	00 00                	add    BYTE PTR [eax],al
#   21:	00 00                	add    BYTE PTR [eax],al
#   23:	00 00                	add    BYTE PTR [eax],al
#   25:	02 50 00             	add    dl,BYTE PTR [eax+0x0]
#   28:	00 00                	add    BYTE PTR [eax],al
#   2a:	02 d1                	add    dl,cl
#   2c:	17                   	pop    ss
#   2d:	31 00                	xor    DWORD PTR [eax],eax
#   2f:	00 00                	add    BYTE PTR [eax],al
#   31:	03 04 07             	add    eax,DWORD PTR [edi+eax*1]
#   34:	4e                   	dec    esi
#   35:	01 00                	add    DWORD PTR [eax],eax
#   37:	00 03                	add    BYTE PTR [ebx],al
#   39:	01 06                	add    DWORD PTR [esi],eax
#   3b:	3f                   	aas
#   3c:	01 00                	add    DWORD PTR [eax],eax
#   3e:	00 04 38             	add    BYTE PTR [eax+edi*1],al
#   41:	00 00                	add    BYTE PTR [eax],al
#   43:	00 03                	add    BYTE PTR [ebx],al
#   45:	01 08                	add    DWORD PTR [eax],ecx
#   47:	36 01 00             	add    DWORD PTR ss:[eax],eax
#   4a:	00 03                	add    BYTE PTR [ebx],al
#   4c:	02 07                	add    al,BYTE PTR [edi]
#   4e:	b1 01                	mov    cl,0x1
#   50:	00 00                	add    BYTE PTR [eax],al
#   52:	03 04 07             	add    eax,DWORD PTR [edi+eax*1]
#   55:	49                   	dec    ecx
#   56:	01 00                	add    DWORD PTR [eax],eax
#   58:	00 03                	add    BYTE PTR [ebx],al
#   5a:	01 06                	add    DWORD PTR [esi],eax
#   5c:	38 01                	cmp    BYTE PTR [ecx],al
#   5e:	00 00                	add    BYTE PTR [eax],al
#   60:	03 02                	add    eax,DWORD PTR [edx]
#   62:	05 46 00 00 00       	add    eax,0x46
#   67:	05 04 05 69 6e       	add    eax,0x6e690504
#   6c:	74 00                	je     6e <_init-0xf92>
#   6e:	02 c5                	add    al,ch
#   70:	00 00                	add    BYTE PTR [eax],al
#   72:	00 03                	add    BYTE PTR [ebx],al
#   74:	2f                   	das
#   75:	2c 7a                	sub    al,0x7a
#   77:	00 00                	add    BYTE PTR [eax],al
#   79:	00 03                	add    BYTE PTR [ebx],al
#   7b:	08 05 b1 00 00 00    	or     BYTE PTR ds:0xb1,al
#   81:	03 08                	add    ecx,DWORD PTR [eax]
#   83:	07                   	pop    es
#   84:	44                   	inc    esp
#   85:	01 00                	add    DWORD PTR [eax],eax
#   87:	00 02                	add    BYTE PTR [edx],al
#   89:	ef                   	out    dx,eax
#   8a:	01 00                	add    DWORD PTR [eax],eax
#   8c:	00 03                	add    BYTE PTR [ebx],al
#   8e:	98                   	cwde
#   8f:	19 94 00 00 00 03 04 	sbb    DWORD PTR [eax+eax*1+0x4030000],edx
#   96:	05 b6 00 00 00       	add    eax,0xb6
#   9b:	02 e5                	add    ah,ch
#   9d:	01 00                	add    DWORD PTR [eax],eax
#   9f:	00 03                	add    BYTE PTR [ebx],al
#   a1:	99                   	cdq
#   a2:	1b 6e 00             	sbb    ebp,DWORD PTR [esi+0x0]
#   a5:	00 00                	add    BYTE PTR [eax],al
#   a7:	06                   	push   es
#   a8:	04 07                	add    al,0x7
#   aa:	04 38                	add    al,0x38
#   ac:	00 00                	add    BYTE PTR [eax],al
#   ae:	00 08                	add    BYTE PTR [eax],cl
#   b0:	2d 01 00 00 94       	sub    eax,0x94000001
#   b5:	04 31                	add    al,0x31
#   b7:	08 36                	or     BYTE PTR [esi],dh
#   b9:	02 00                	add    al,BYTE PTR [eax]
#   bb:	00 09                	add    BYTE PTR [ecx],cl
#   bd:	73 00                	jae    bf <_init-0xf41>
#   bf:	00 00                	add    BYTE PTR [eax],al
#   c1:	04 33                	add    al,0x33
#   c3:	07                   	pop    es
#   c4:	67 00 00             	add    BYTE PTR [bx+si],al
#   c7:	00 00                	add    BYTE PTR [eax],al
#   c9:	09 88 01 00 00 04    	or     DWORD PTR [eax+0x4000001],ecx
#   cf:	36 09 a9 00 00 00 04 	or     DWORD PTR ss:[ecx+0x4000000],ebp
#   d6:	09 90 00 00 00 04    	or     DWORD PTR [eax+0x4000000],edx
#   dc:	37                   	aaa
#   dd:	09 a9 00 00 00 08    	or     DWORD PTR [ecx+0x8000000],ebp
#   e3:	09 30                	or     DWORD PTR [eax],esi
#   e5:	02 00                	add    al,BYTE PTR [eax]
#   e7:	00 04 38             	add    BYTE PTR [eax+edi*1],al
#   ea:	09 a9 00 00 00 0c    	or     DWORD PTR [ecx+0xc000000],ebp
#   f0:	09 70 01             	or     DWORD PTR [eax+0x1],esi
#   f3:	00 00                	add    BYTE PTR [eax],al
#   f5:	04 39                	add    al,0x39
#   f7:	09 a9 00 00 00 10    	or     DWORD PTR [ecx+0x10000000],ebp
#   fd:	09 65 00             	or     DWORD PTR [ebp+0x0],esp
#  100:	00 00                	add    BYTE PTR [eax],al
#  102:	04 3a                	add    al,0x3a
#  104:	09 a9 00 00 00 14    	or     DWORD PTR [ecx+0x14000000],ebp
#  10a:	09 d7                	or     edi,edx
#  10c:	01 00                	add    DWORD PTR [eax],eax
#  10e:	00 04 3b             	add    BYTE PTR [ebx+edi*1],al
#  111:	09 a9 00 00 00 18    	or     DWORD PTR [ecx+0x18000000],ebp
#  117:	09 7a 00             	or     DWORD PTR [edx+0x0],edi
#  11a:	00 00                	add    BYTE PTR [eax],al
#  11c:	04 3c                	add    al,0x3c
#  11e:	09 a9 00 00 00 1c    	or     DWORD PTR [ecx+0x1c000000],ebp
#  124:	09 00                	or     DWORD PTR [eax],eax
#  126:	00 00                	add    BYTE PTR [eax],al
#  128:	00 04 3d 09 a9 00 00 	add    BYTE PTR [edi*1+0xa909],al
#  12f:	00 20                	add    BYTE PTR [eax],ah
#  131:	09 4d 02             	or     DWORD PTR [ebp+0x2],ecx
#  134:	00 00                	add    BYTE PTR [eax],al
#  136:	04 40                	add    al,0x40
#  138:	09 a9 00 00 00 24    	or     DWORD PTR [ecx+0x24000000],ebp
#  13e:	09 0c 02             	or     DWORD PTR [edx+eax*1],ecx
#  141:	00 00                	add    BYTE PTR [eax],al
#  143:	04 41                	add    al,0x41
#  145:	09 a9 00 00 00 28    	or     DWORD PTR [ecx+0x28000000],ebp
#  14b:	09 39                	or     DWORD PTR [ecx],edi
#  14d:	00 00                	add    BYTE PTR [eax],al
#  14f:	00 04 42             	add    BYTE PTR [edx+eax*2],al
#  152:	09 a9 00 00 00 2c    	or     DWORD PTR [ecx+0x2c000000],ebp
#  158:	09 87 00 00 00 04    	or     DWORD PTR [edi+0x4000000],eax
#  15e:	44                   	inc    esp
#  15f:	16                   	push   ss
#  160:	4f                   	dec    edi
#  161:	02 00                	add    al,BYTE PTR [eax]
#  163:	00 30                	add    BYTE PTR [eax],dh
# ...
#   cd:	63 74 5f 46          	arpl   WORD PTR [edi+ebx*2+0x46],si
#   d1:	49                   	dec    ecx
#   d2:	4c                   	dec    esp
#   d3:	45                   	inc    ebp
#   d4:	2e 68 00 04 00 00    	cs push 0x400
#   da:	46                   	inc    esi
#   db:	49                   	dec    ecx
#   dc:	4c                   	dec    esp
#   dd:	45                   	inc    ebp
#   de:	2e 68 00 04 00 00    	cs push 0x400
#   e4:	73 74                	jae    15a <_init-0xea6>
#   e6:	64 69 6f 2e 68 00 05 	imul   ebp,DWORD PTR fs:[edi+0x2e],0x50068
#   ed:	00
#   ee:	00 73 79             	add    BYTE PTR [ebx+0x79],dh
#   f1:	73 5f                	jae    152 <_init-0xeae>
#   f3:	65 72 72             	gs jb  168 <_init-0xe98>
#   f6:	6c                   	ins    BYTE PTR es:[edi],dx
#   f7:	69 73 74 2e 68 00 03 	imul   esi,DWORD PTR [ebx+0x74],0x300682e
#   fe:	00 00                	add    BYTE PTR [eax],al
#  100:	00 05 0c 00 05 02    	add    BYTE PTR ds:0x205000c,al
#  106:	99                   	cdq
#  107:	11 00                	adc    DWORD PTR [eax],eax
#  109:	00 14 05 05 08 83 05 	add    BYTE PTR [eax*1+0x5830805],dl
#  110:	0c 08                	or     al,0x8
#  112:	3d 05 01 59 02       	cmp    eax,0x2590105
#  117:	0a 00                	or     al,BYTE PTR [eax]
#  119:	01 01                	add    DWORD PTR [ecx],eax
#
# Disassembly of section .debug_str:
#
# 00000000 <.debug_str>:
#    0:	5f                   	pop    edi
#    1:	49                   	dec    ecx
#    2:	4f                   	dec    edi
#    3:	5f                   	pop    edi
#    4:	62 75 66             	bound  esi,QWORD PTR [ebp+0x66]
#    7:	5f                   	pop    edi
#    8:	65 6e                	outs   dx,BYTE PTR gs:[esi]
#    a:	64 00 2e             	add    BYTE PTR fs:[esi],ch
#    d:	2f                   	das
#    e:	64 65 6d             	fs gs ins DWORD PTR es:[edi],dx
#   11:	6f                   	outs   dx,DWORD PTR ds:[esi]
#   12:	2d 70 72 6f 67       	sub    eax,0x676f7270
#   17:	72 61                	jb     7a <_init-0xf86>
#   19:	6d                   	ins    DWORD PTR es:[edi],dx
#   1a:	73 2f                	jae    4b <_init-0xfb5>
#   1c:	68 65 6c 6c 6f       	push   0x6f6c6c65
#   21:	2e 63 00             	arpl   WORD PTR cs:[eax],ax
#   24:	5f                   	pop    edi
#   25:	6f                   	outs   dx,DWORD PTR ds:[esi]
#   26:	6c                   	ins    BYTE PTR es:[edi],dx
#   27:	64 5f                	fs pop edi
#   29:	6f                   	outs   dx,DWORD PTR ds:[esi]
#   2a:	66 66 73 65          	data16 data16 jae 93 <_init-0xf6d>
#   2e:	74 00                	je     30 <_init-0xfd0>
#   30:	73 79                	jae    ab <_init-0xf55>
#   32:	73 5f                	jae    93 <_init-0xf6d>
#   34:	6e                   	outs   dx,BYTE PTR ds:[esi]
#   35:	65 72 72             	gs jb  aa <_init-0xf56>
#   38:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#   3b:	4f                   	dec    edi
#   3c:	5f                   	pop    edi
#   3d:	73 61                	jae    a0 <_init-0xf60>
#   3f:	76 65                	jbe    a6 <_init-0xf5a>
#   41:	5f                   	pop    edi
#   42:	65 6e                	outs   dx,BYTE PTR gs:[esi]
#   44:	64 00 73 68          	add    BYTE PTR fs:[ebx+0x68],dh
#   48:	6f                   	outs   dx,DWORD PTR ds:[esi]
#   49:	72 74                	jb     bf <_init-0xf41>
#   4b:	20 69 6e             	and    BYTE PTR [ecx+0x6e],ch
#   4e:	74 00                	je     50 <_init-0xfb0>
#   50:	73 69                	jae    bb <_init-0xf45>
#   52:	7a 65                	jp     b9 <_init-0xf47>
#   54:	5f                   	pop    edi
#   55:	74 00                	je     57 <_init-0xfa9>
#   57:	5f                   	pop    edi
#   58:	66 72 65             	data16 jb c0 <_init-0xf40>
#   5b:	65 72 65             	gs jb  c3 <_init-0xf3d>
#   5e:	73 5f                	jae    bf <_init-0xf41>
#   60:	6c                   	ins    BYTE PTR es:[edi],dx
#   61:	69 73 74 00 5f 49 4f 	imul   esi,DWORD PTR [ebx+0x74],0x4f495f00
#   68:	5f                   	pop    edi
#   69:	77 72                	ja     dd <_init-0xf23>
#   6b:	69 74 65 5f 70 74 72 	imul   esi,DWORD PTR [ebp+eiz*2+0x5f],0x727470
#   72:	00
#   73:	5f                   	pop    edi
#   74:	66 6c                	data16 ins BYTE PTR es:[edi],dx
#   76:	61                   	popa
#   77:	67 73 00             	addr16 jae 7a <_init-0xf86>
#   7a:	5f                   	pop    edi
#   7b:	49                   	dec    ecx
#   7c:	4f                   	dec    edi
#   7d:	5f                   	pop    edi
#   7e:	62 75 66             	bound  esi,QWORD PTR [ebp+0x66]
#   81:	5f                   	pop    edi
#   82:	62 61 73             	bound  esp,QWORD PTR [ecx+0x73]
#   85:	65 00 5f 6d          	add    BYTE PTR gs:[edi+0x6d],bl
#   89:	61                   	popa
#   8a:	72 6b                	jb     f7 <_init-0xf09>
#   8c:	65 72 73             	gs jb  102 <_init-0xefe>
#   8f:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#   92:	4f                   	dec    edi
#   93:	5f                   	pop    edi
#   94:	72 65                	jb     fb <_init-0xf05>
#   96:	61                   	popa
#   97:	64 5f                	fs pop edi
#   99:	65 6e                	outs   dx,BYTE PTR gs:[esi]
#   9b:	64 00 5f 66          	add    BYTE PTR fs:[edi+0x66],bl
#   9f:	72 65                	jb     106 <_init-0xefa>
#   a1:	65 72 65             	gs jb  109 <_init-0xef7>
#   a4:	73 5f                	jae    105 <_init-0xefb>
#   a6:	62 75 66             	bound  esi,QWORD PTR [ebp+0x66]
#   a9:	00 73 74             	add    BYTE PTR [ebx+0x74],dh
#   ac:	64 65 72 72          	fs gs jb 122 <_init-0xede>
#   b0:	00 6c 6f 6e          	add    BYTE PTR [edi+ebp*2+0x6e],ch
#   b4:	67 20 6c 6f          	and    BYTE PTR [si+0x6f],ch
#   b8:	6e                   	outs   dx,BYTE PTR ds:[esi]
#   b9:	67 20 69 6e          	and    BYTE PTR [bx+di+0x6e],ch
#   bd:	74 00                	je     bf <_init-0xf41>
#   bf:	5f                   	pop    edi
#   c0:	6c                   	ins    BYTE PTR es:[edi],dx
#   c1:	6f                   	outs   dx,DWORD PTR ds:[esi]
#   c2:	63 6b 00             	arpl   WORD PTR [ebx+0x0],bp
#   c5:	5f                   	pop    edi
#   c6:	5f                   	pop    edi
#   c7:	69 6e 74 36 34 5f 74 	imul   ebp,DWORD PTR [esi+0x74],0x745f3436
#   ce:	00 5f 63             	add    BYTE PTR [edi+0x63],bl
#   d1:	75 72                	jne    145 <_init-0xebb>
#   d3:	5f                   	pop    edi
#   d4:	63 6f 6c             	arpl   WORD PTR [edi+0x6c],bp
#   d7:	75 6d                	jne    146 <_init-0xeba>
#   d9:	6e                   	outs   dx,BYTE PTR ds:[esi]
#   da:	00 47 4e             	add    BYTE PTR [edi+0x4e],al
#   dd:	55                   	push   ebp
#   de:	20 43 31             	and    BYTE PTR [ebx+0x31],al
#   e1:	37                   	aaa
#   e2:	20 39                	and    BYTE PTR [ecx],bh
#   e4:	2e 32 2e             	xor    ch,BYTE PTR cs:[esi]
#   e7:	31 20                	xor    DWORD PTR [eax],esp
#   e9:	32 30                	xor    dh,BYTE PTR [eax]
#   eb:	32 30                	xor    dh,BYTE PTR [eax]
#   ed:	30 31                	xor    BYTE PTR [ecx],dh
#   ef:	32 33                	xor    dh,BYTE PTR [ebx]
#   f1:	20 2d 6d 74 75 6e    	and    BYTE PTR ds:0x6e75746d,ch
#   f7:	65 3d 67 65 6e 65    	gs cmp eax,0x656e6567
#   fd:	72 69                	jb     168 <_init-0xe98>
#   ff:	63 20                	arpl   WORD PTR [eax],sp
#  101:	2d 6d 61 72 63       	sub    eax,0x6372616d
#  106:	68 3d 69 36 38       	push   0x3836693d
#  10b:	36 20 2d 67 20 2d 66 	and    BYTE PTR ss:0x662d2067,ch
#  112:	61                   	popa
#  113:	73 79                	jae    18e <_init-0xe72>
#  115:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  116:	63 68 72             	arpl   WORD PTR [eax+0x72],bp
#  119:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  11a:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  11b:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  11c:	75 73                	jne    191 <_init-0xe6f>
#  11e:	2d 75 6e 77 69       	sub    eax,0x69776e75
#  123:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  124:	64 2d 74 61 62 6c    	fs sub eax,0x6c626174
#  12a:	65 73 00             	gs jae 12d <_init-0xed3>
#  12d:	5f                   	pop    edi
#  12e:	49                   	dec    ecx
#  12f:	4f                   	dec    edi
#  130:	5f                   	pop    edi
#  131:	46                   	inc    esi
#  132:	49                   	dec    ecx
#  133:	4c                   	dec    esp
#  134:	45                   	inc    ebp
#  135:	00 75 6e             	add    BYTE PTR [ebp+0x6e],dh
#  138:	73 69                	jae    1a3 <_init-0xe5d>
#  13a:	67 6e                	outs   dx,BYTE PTR ds:[si]
#  13c:	65 64 20 63 68       	gs and BYTE PTR fs:[ebx+0x68],ah
#  141:	61                   	popa
#  142:	72 00                	jb     144 <_init-0xebc>
#  144:	6c                   	ins    BYTE PTR es:[edi],dx
#  145:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  146:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  147:	67 20 6c 6f          	and    BYTE PTR [si+0x6f],ch
#  14b:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  14c:	67 20 75 6e          	and    BYTE PTR [di+0x6e],dh
#  150:	73 69                	jae    1bb <_init-0xe45>
#  152:	67 6e                	outs   dx,BYTE PTR ds:[si]
#  154:	65 64 20 69 6e       	gs and BYTE PTR fs:[ecx+0x6e],ch
#  159:	74 00                	je     15b <_init-0xea5>
#  15b:	5f                   	pop    edi
#  15c:	49                   	dec    ecx
#  15d:	4f                   	dec    edi
#  15e:	5f                   	pop    edi
#  15f:	6d                   	ins    DWORD PTR es:[edi],dx
#  160:	61                   	popa
#  161:	72 6b                	jb     1ce <_init-0xe32>
#  163:	65 72 00             	gs jb  166 <_init-0xe9a>
#  166:	5f                   	pop    edi
#  167:	73 68                	jae    1d1 <_init-0xe2f>
#  169:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  16a:	72 74                	jb     1e0 <_init-0xe20>
#  16c:	62 75 66             	bound  esi,QWORD PTR [ebp+0x66]
#  16f:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  172:	4f                   	dec    edi
#  173:	5f                   	pop    edi
#  174:	77 72                	ja     1e8 <_init-0xe18>
#  176:	69 74 65 5f 62 61 73 	imul   esi,DWORD PTR [ebp+eiz*2+0x5f],0x65736162
#  17d:	65
#  17e:	00 5f 75             	add    BYTE PTR [edi+0x75],bl
#  181:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  182:	75 73                	jne    1f7 <_init-0xe09>
#  184:	65 64 32 00          	gs xor al,BYTE PTR fs:[eax]
#  188:	5f                   	pop    edi
#  189:	49                   	dec    ecx
#  18a:	4f                   	dec    edi
#  18b:	5f                   	pop    edi
#  18c:	72 65                	jb     1f3 <_init-0xe0d>
#  18e:	61                   	popa
#  18f:	64 5f                	fs pop edi
#  191:	70 74                	jo     207 <_init-0xdf9>
#  193:	72 00                	jb     195 <_init-0xe6b>
#  195:	2f                   	das
#  196:	72 6f                	jb     207 <_init-0xdf9>
#  198:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  199:	74 2f                	je     1ca <_init-0xe36>
#  19b:	48                   	dec    eax
#  19c:	61                   	popa
#  19d:	63 6b 69             	arpl   WORD PTR [ebx+0x69],bp
#  1a0:	6e                   	outs   dx,BYTE PTR ds:[esi]
#  1a1:	67 4e                	addr16 dec esi
#  1a3:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  1a4:	74 65                	je     20b <_init-0xdf5>
#  1a6:	62 6f 6f             	bound  ebp,QWORD PTR [edi+0x6f]
#  1a9:	6b 73 00 6d          	imul   esi,DWORD PTR [ebx+0x0],0x6d
#  1ad:	61                   	popa
#  1ae:	69 6e 00 73 68 6f 72 	imul   ebp,DWORD PTR [esi+0x0],0x726f6873
#  1b5:	74 20                	je     1d7 <_init-0xe29>
#  1b7:	75 6e                	jne    227 <_init-0xdd9>
#  1b9:	73 69                	jae    224 <_init-0xddc>
#  1bb:	67 6e                	outs   dx,BYTE PTR ds:[si]
#  1bd:	65 64 20 69 6e       	gs and BYTE PTR fs:[ecx+0x6e],ch
#  1c2:	74 00                	je     1c4 <_init-0xe3c>
#  1c4:	5f                   	pop    edi
#  1c5:	5f                   	pop    edi
#  1c6:	70 61                	jo     229 <_init-0xdd7>
#  1c8:	64 35 00 5f 49 4f    	fs xor eax,0x4f495f00
#  1ce:	5f                   	pop    edi
#  1cf:	63 6f 64             	arpl   WORD PTR [edi+0x64],bp
#  1d2:	65 63 76 74          	arpl   WORD PTR gs:[esi+0x74],si
#  1d6:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  1d9:	4f                   	dec    edi
#  1da:	5f                   	pop    edi
#  1db:	77 72                	ja     24f <_init-0xdb1>
#  1dd:	69 74 65 5f 65 6e 64 	imul   esi,DWORD PTR [ebp+eiz*2+0x5f],0x646e65
#  1e4:	00
#  1e5:	5f                   	pop    edi
#  1e6:	5f                   	pop    edi
#  1e7:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  1e8:	66 66 36 34 5f       	data16 data16 ss xor al,0x5f
#  1ed:	74 00                	je     1ef <_init-0xe11>
#  1ef:	5f                   	pop    edi
#  1f0:	5f                   	pop    edi
#  1f1:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  1f2:	66 66 5f             	data16 pop di
#  1f5:	74 00                	je     1f7 <_init-0xe09>
#  1f7:	5f                   	pop    edi
#  1f8:	63 68 61             	arpl   WORD PTR [eax+0x61],bp
#  1fb:	69 6e 00 5f 49 4f 5f 	imul   ebp,DWORD PTR [esi+0x0],0x5f4f495f
#  202:	77 69                	ja     26d <_init-0xd93>
#  204:	64 65 5f             	fs gs pop edi
#  207:	64 61                	fs popa
#  209:	74 61                	je     26c <_init-0xd94>
#  20b:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  20e:	4f                   	dec    edi
#  20f:	5f                   	pop    edi
#  210:	62 61 63             	bound  esp,QWORD PTR [ecx+0x63]
#  213:	6b 75 70 5f          	imul   esi,DWORD PTR [ebp+0x70],0x5f
#  217:	62 61 73             	bound  esp,QWORD PTR [ecx+0x73]
#  21a:	65 00 73 74          	add    BYTE PTR gs:[ebx+0x74],dh
#  21e:	64 69 6e 00 5f 66 6c 	imul   ebp,DWORD PTR fs:[esi+0x0],0x616c665f
#  225:	61
#  226:	67 73 32             	addr16 jae 25b <_init-0xda5>
#  229:	00 5f 6d             	add    BYTE PTR [edi+0x6d],bl
#  22c:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  22d:	64 65 00 5f 49       	fs add BYTE PTR gs:[edi+0x49],bl
#  232:	4f                   	dec    edi
#  233:	5f                   	pop    edi
#  234:	72 65                	jb     29b <_init-0xd65>
#  236:	61                   	popa
#  237:	64 5f                	fs pop edi
#  239:	62 61 73             	bound  esp,QWORD PTR [ecx+0x73]
#  23c:	65 00 5f 76          	add    BYTE PTR gs:[edi+0x76],bl
#  240:	74 61                	je     2a3 <_init-0xd5d>
#  242:	62 6c 65 5f          	bound  ebp,QWORD PTR [ebp+eiz*2+0x5f]
#  246:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  247:	66 66 73 65          	data16 data16 jae 2b0 <_init-0xd50>
#  24b:	74 00                	je     24d <_init-0xdb3>
#  24d:	5f                   	pop    edi
#  24e:	49                   	dec    ecx
#  24f:	4f                   	dec    edi
#  250:	5f                   	pop    edi
#  251:	73 61                	jae    2b4 <_init-0xd4c>
#  253:	76 65                	jbe    2ba <_init-0xd46>
#  255:	5f                   	pop    edi
#  256:	62 61 73             	bound  esp,QWORD PTR [ecx+0x73]
#  259:	65 00 73 79          	add    BYTE PTR gs:[ebx+0x79],dh
#  25d:	73 5f                	jae    2be <_init-0xd42>
#  25f:	65 72 72             	gs jb  2d4 <_init-0xd2c>
#  262:	6c                   	ins    BYTE PTR es:[edi],dx
#  263:	69 73 74 00 5f 66 69 	imul   esi,DWORD PTR [ebx+0x74],0x69665f00
#  26a:	6c                   	ins    BYTE PTR es:[edi],dx
#  26b:	65 6e                	outs   dx,BYTE PTR gs:[esi]
#  26d:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  26e:	00 73 74             	add    BYTE PTR [ebx+0x74],dh
#  271:	64 6f                	outs   dx,DWORD PTR fs:[esi]
#  273:	75 74                	jne    2e9 <_init-0xd17>
#  275:	00 5f 49             	add    BYTE PTR [edi+0x49],bl
#  278:	4f                   	dec    edi
#  279:	5f                   	pop    edi
#  27a:	6c                   	ins    BYTE PTR es:[edi],dx
#  27b:	6f                   	outs   dx,DWORD PTR ds:[esi]
#  27c:	63 6b 5f             	arpl   WORD PTR [ebx+0x5f],bp
#  27f:	74 00                	je     281 <_init-0xd7f>

# %%
! objdump -M intel -D hello | grep -A20 main.:
# Out:
# 00001199 <main>:
#     1199:	8d 4c 24 04          	lea    ecx,[esp+0x4]
#     119d:	83 e4 f0             	and    esp,0xfffffff0
#     11a0:	ff 71 fc             	push   DWORD PTR [ecx-0x4]
#     11a3:	55                   	push   ebp
#     11a4:	89 e5                	mov    ebp,esp
#     11a6:	53                   	push   ebx
#     11a7:	51                   	push   ecx
#     11a8:	e8 28 00 00 00       	call   11d5 <__x86.get_pc_thunk.ax>
#     11ad:	05 53 2e 00 00       	add    eax,0x2e53
#     11b2:	83 ec 0c             	sub    esp,0xc
#     11b5:	8d 90 08 e0 ff ff    	lea    edx,[eax-0x1ff8]
#     11bb:	52                   	push   edx
#     11bc:	89 c3                	mov    ebx,eax
#     11be:	e8 6d fe ff ff       	call   1030 <puts@plt>
#     11c3:	83 c4 10             	add    esp,0x10
#     11c6:	b8 00 00 00 00       	mov    eax,0x0
#     11cb:	8d 65 f8             	lea    esp,[ebp-0x8]
#     11ce:	59                   	pop    ecx
#     11cf:	5b                   	pop    ebx
#     11d0:	5d                   	pop    ebp
